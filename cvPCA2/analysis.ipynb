# %%
#!/usr/bin/env python3
"""
Two-stage cvPCA pipeline with an initial PCA bottleneck:

1) ViT:
   - Softmax + CLR on logits for natural scenes
   - PCA → keep PCs up to VAR_CUTOFF variance

2) Neural:
   (a) Preprocess:
       - Load deconvolved responses
       - Select AREA_NAME
       - Reshape to (neurons × images × trials × time)
       - Compute stimulus-locked means
   (b) PCA on stimulus-locked means (all trials):
       - Xa = R_all.T  (images × neurons)
       - PCA → keep PCs up to VAR_CUTOFF variance
       - Get neural PC scores: Xa_pca (images × n_neural_pca)
   (c) cvPCA in neural PC space:
       - Split trials into even/odd → R_even, R_odd
       - Project to PCA space → Xe_pca, Xo_pca
       - cvPCA (Pachitariu-style) on these PC scores
       - Get neural cvPCA basis inside PCA space + shared variances
       - Get stimulus-locked neural cvPCA scores Zb_cv (images × n_cvpca)

3) Cross-covariance SVD:
   - Between ViT PC scores Zv and neural cvPCA scores Zb_cv
   - SVD of cross-covariance → shared directions U_cv, V_cv

4) Variance explained in original neural PC data:
   - Map cross-covariance components back into the original neural PCA space
   - Compute fraction of variance in Xa_pca explained by those components
"""

import numpy as np
import pickle
from sklearn.decomposition import PCA
from scipy.special import softmax
from skbio.stats.composition import clr

# ---------------------------------------------------------------
# CONFIG
# ---------------------------------------------------------------
VIT_PATH    = '/home/maria/Documents/HuggingMouseData/MouseViTEmbeddings/google_vit-base-patch16-224_embeddings_logits.pkl'
NEURAL_PATH = '/home/maria/LuckyMouse/pixel_transformer_neuro/data/processed/hybrid_neural_responses.npy'
AREAS_PATH  = '/home/maria/MITNeuralComputation/visualization/brain_area.npy'

AREA_NAME   = 'VISp'
AREA_NAME='VISrl'
N_IMAGES    = 118
N_TRIALS    = 50
VAR_CUTOFF  = 0.90
RANDOM_SEED = 42

rng = np.random.default_rng(RANDOM_SEED)

# ===============================================================
# STEP 1: ViT preprocessing (softmax + CLR + PCA)
# ===============================================================
print("🔹 Loading ViT embeddings...")
with open(VIT_PATH, 'rb') as f:
    vit_logits = pickle.load(f)['natural_scenes']  # (N_IMAGES × D_vit)

Xv = np.asarray(vit_logits)
Xv = softmax(Xv, axis=1)          # probabilities over classes
Xv = clr(Xv + 1e-12)              # CLR transform

print("🔹 PCA on ViT CLR embeddings...")
vit_pca_full = PCA(random_state=RANDOM_SEED).fit(Xv)
vit_cumvar = np.cumsum(vit_pca_full.explained_variance_ratio_)
vit_ncomp = np.searchsorted(vit_cumvar, VAR_CUTOFF) + 1

vit_pca = PCA(n_components=vit_ncomp, random_state=RANDOM_SEED)
Zv = vit_pca.fit_transform(Xv)    # (images × vit_ncomp)

print(f"✅ ViT PCs covering {VAR_CUTOFF*100:.0f}% variance: {vit_ncomp}")

# ===============================================================
# STEP 2: Neural preprocessing + FIRST PCA (to 90% var)
# ===============================================================
print(f"\n🔹 Loading neural responses, area = {AREA_NAME}...")
dat_all = np.load(NEURAL_PATH, mmap_mode='r')   # (n_neurons_total × (images*trials*time))
areas = np.load(AREAS_PATH, allow_pickle=True)  # (n_neurons_total,)

area_mask = (areas == AREA_NAME)
dat = dat_all[area_mask]                        # (n_neurons_area × n_total)
n_neurons, n_total = dat.shape

# Infer time bins
n_time = n_total // (N_IMAGES * N_TRIALS)
if N_IMAGES * N_TRIALS * n_time != n_total:
    raise ValueError(f"Inferred n_time={n_time} inconsistent with data shape.")

print(f"   → {n_neurons} neurons, n_total={n_total}, inferred n_time={n_time}")

# Reshape to (neurons × images × trials × time)
dat = dat.reshape(n_neurons, N_IMAGES, N_TRIALS, n_time)

# Stimulus-locked means:
# - R_even, R_odd: for cvPCA
# - R_all: all trials, for the initial PCA
even_idx = np.arange(0, N_TRIALS, 2)
odd_idx  = np.arange(1, N_TRIALS, 2)
print(f"   → Even trials: {even_idx.size}, odd trials: {odd_idx.size}")

R_even = dat[:, :, even_idx, :].mean(axis=(2, 3))   # (neurons × images)
R_odd  = dat[:, :, odd_idx,  :].mean(axis=(2, 3))   # (neurons × images)
R_all  = dat.mean(axis=(2, 3))                      # (neurons × images)

# For PCA: samples = images, features = neurons
Xa = R_all.T    # (images × neurons)
Xe = R_even.T   # (images × neurons)
Xo = R_odd.T    # (images × neurons)

print("\n🔹 FIRST PCA on stimulus-locked neural responses (all trials)...")
neural_pca_full = PCA(random_state=RANDOM_SEED).fit(Xa)
neural_cumvar = np.cumsum(neural_pca_full.explained_variance_ratio_)
neural_ncomp = np.searchsorted(neural_cumvar, VAR_CUTOFF) + 1

neural_pca = PCA(n_components=neural_ncomp, random_state=RANDOM_SEED)
Xa_pca = neural_pca.fit_transform(Xa)   # (images × neural_ncomp)
Xe_pca = neural_pca.transform(Xe)       # (images × neural_ncomp)
Xo_pca = neural_pca.transform(Xo)       # (images × neural_ncomp)

print(f"✅ Neural PCs (first stage) covering {VAR_CUTOFF*100:.0f}% variance: {neural_ncomp}")

# PCA basis in neuron space (neurons × neural_ncomp)
# sklearn: components_ is (n_components × n_features)
W_pca_neurons = neural_pca.components_.T

# ===============================================================
# STEP 3: cvPCA in neural PCA space
# ===============================================================
print("\n🔹 Running cvPCA on neural PCA scores (stimulus-locked)...")

n_stim = N_IMAGES

# Xe_pca and Xo_pca are already centered using the same mean in neuron space;
# we can treat them as zero-mean PC scores.
Xe0 = Xe_pca
Xo0 = Xo_pca

# Covariance of train (even) half in PCA space
Cb_pca = Xe0.T @ Xe0 / (n_stim - 1)      # (neural_ncomp × neural_ncomp)

# Eigen-decomposition in PCA space
eigvals, V_pca = np.linalg.eigh(Cb_pca)
idx = np.argsort(eigvals)[::-1]
eigvals = eigvals[idx]
V_pca = V_pca[:, idx]                    # (neural_ncomp × neural_ncomp)

# Project both halves onto these components (still in PCA space)
S1 = Xe0 @ V_pca                         # (images × neural_ncomp)
S2 = Xo0 @ V_pca                         # (images × neural_ncomp)

# Cross-validated variance per component
lam_cv = np.sum(S1 * S2, axis=0) / (n_stim - 1)   # (neural_ncomp,)

# Clamp negatives (noise)
lam_cv_pos = np.maximum(lam_cv, 0.0)
total_shared = lam_cv_pos.sum()
if total_shared <= 0:
    raise RuntimeError("Total shared variance (cvPCA) non-positive. Check data/splits.")

shared_frac = lam_cv_pos / total_shared
cum_shared_frac = np.cumsum(shared_frac)

# Pick number of cvPCA components by shared variance cutoff
brain_ncomp = np.searchsorted(cum_shared_frac, VAR_CUTOFF) + 1
brain_ncomp = min(brain_ncomp, V_pca.shape[1])

print("===== Neural cvPCA (in PCA space) =====")
for i in range(brain_ncomp):
    print(f"cvPC {i+1:2d}: shared var = {lam_cv_pos[i]:.6f} | "
          f"fraction = {shared_frac[i]*100:5.2f}% | "
          f"cumulative = {cum_shared_frac[i]*100:5.2f}%")

print(f"\n✅ Using first {brain_ncomp} cvPCA components as neural stimulus-locked basis "
      f"in PCA space (covering {cum_shared_frac[brain_ncomp-1]*100:.2f}% shared variance).")

# Neural cvPCA basis inside PCA space (neural_ncomp × brain_ncomp)
W_cvpca_pca = V_pca[:, :brain_ncomp]

# Now get neural cvPCA scores for ALL trials (Xa_pca) in this basis:
Zb_cv = Xa_pca @ W_cvpca_pca           # (images × brain_ncomp)

# Optionally, you can also get cvPCA basis back in neuron space:
# W_neural_cv = W_pca_neurons @ W_cvpca_pca   # (neurons × brain_ncomp)


# ===============================================================
# STEP 4: Cross-covariance between ViT PCs and neural cvPCA scores
# ===============================================================
print("\n🔹 Cross-covariance SVD between ViT PCs and neural cvPCA scores...")

# Center across images
Zv0 = Zv - Zv.mean(axis=0, keepdims=True)      # (images × vit_ncomp)
Zb0 = Zb_cv - Zb_cv.mean(axis=0, keepdims=True)  # (images × brain_ncomp)

# Cross-covariance
C_vb = (Zv0.T @ Zb0) / (n_stim - 1)            # (vit_ncomp × brain_ncomp)

# SVD of cross-covariance
U_cv, S_cv, Vt_cv = np.linalg.svd(C_vb, full_matrices=False)
V_cv = Vt_cv.T                                  # (brain_ncomp × r)

shared_cov_frac = (S_cv**2) / np.sum(S_cv**2)

print("===== Cross-covariance components (ViT ↔ neural cvPCA) =====")
for i, (s, frac) in enumerate(zip(S_cv, shared_cov_frac), start=1):
    print(f"Component {i:2d}: singular value = {s:.6f} | "
          f"cross-covariance fraction = {frac*100:5.2f}%")


# ===============================================================
# STEP 5: Variance explained in ORIGINAL neural PC data
#         by cross-covariance components
# ===============================================================
print("\n🔹 Variance explained in ORIGINAL neural PC data by cross-covariance components...")

# Original neural PC scores from FIRST PCA:
# Xa_pca: (images × neural_ncomp)
Xa_pca0 = Xa_pca - Xa_pca.mean(axis=0, keepdims=True)

# Total variance in original neural PCA space
total_var_neural_pca = np.sum(np.var(Xa_pca0, axis=0, ddof=1))

# Map cross-cov components from cvPCA space back into original neural PCA space:
# W_cvpca_pca: (neural_ncomp × brain_ncomp)
# V_cv:        (brain_ncomp × r)
# → B_pca:     (neural_ncomp × r), directions in original neural PCA space
B_pca = W_cvpca_pca @ V_cv                   # (neural_ncomp × r)

# Project original neural PC scores onto these cross-cov directions
Xb_cc_pca = Xa_pca0 @ B_pca                  # (images × r)

# Variance per cross-cov component in original neural PCA space
var_cc = np.var(Xb_cc_pca, axis=0, ddof=1)   # (r,)
frac_cc = var_cc / total_var_neural_pca
cum_frac_cc = np.cumsum(frac_cc)

print("===== Neural PCA variance explained by cross-covariance components =====")
for i, (f, cf) in enumerate(zip(frac_cc, cum_frac_cc), start=1):
    print(f"Cross-cov comp {i:2d}: "
          f"explained var in neural PCA space = {f*100:5.2f}% | "
          f"cumulative = {cf*100:5.2f}%")

print(f"\n✅ Total variance in ORIGINAL neural PC data accounted for "
      f"(sum over all cross-cov comps): {frac_cc.sum()*100:.2f}%")

# ===============================================================
# STEP 6: Save everything
# ===============================================================
out_name = f"vit_{AREA_NAME}_pca_cvpca_crosscov_results.npz"
np.savez(
    out_name,
    # ViT
    vit_scores=Zv,
    vit_basis=vit_pca.components_,
    vit_explained_var=vit_pca.explained_variance_ratio_,
    # Neural PCA
    neural_pca_scores=Xa_pca,
    neural_pca_basis=W_pca_neurons,
    neural_pca_explained_var=neural_pca.explained_variance_ratio_,
    # Neural cvPCA
    neural_cvpca_basis_pca=W_cvpca_pca,
    neural_cvpca_shared_var=lam_cv_pos[:brain_ncomp],
    neural_cvpca_shared_frac=shared_frac[:brain_ncomp],
    neural_cvpca_scores=Zb_cv,
    # Cross-covariance
    crosscov_matrix=C_vb,
    crosscov_singular_values=S_cv,
    crosscov_vit_basis=U_cv,
    crosscov_neural_cvpca_basis=V_cv,
    # Variance explained in ORIGINAL neural PCA space
    neural_pca_var_per_cc=var_cc,
    neural_pca_var_fraction_per_cc=frac_cc,
)

print(f"💾 Saved results to {out_name}")
# Out:
# 🔹 Loading ViT embeddings...
# 🔹 PCA on ViT CLR embeddings...
# ✅ ViT PCs covering 90% variance: 44
#
# 🔹 Loading neural responses, area = VISp...
#    → 14382 neurons, n_total=5900, inferred n_time=1
#    → Even trials: 25, odd trials: 25
#
# 🔹 FIRST PCA on stimulus-locked neural responses (all trials)...
# ✅ Neural PCs (first stage) covering 90% variance: 87
#
# 🔹 Running cvPCA on neural PCA scores (stimulus-locked)...
# ===== Neural cvPCA (in PCA space) =====
# cvPC  1: shared var = 2.676840 | fraction =  5.94% | cumulative =  5.94%
# cvPC  2: shared var = 1.709752 | fraction =  3.79% | cumulative =  9.73%
# cvPC  3: shared var = 1.561735 | fraction =  3.46% | cumulative = 13.19%
# cvPC  4: shared var = 1.341531 | fraction =  2.98% | cumulative = 16.17%
# cvPC  5: shared var = 1.205600 | fraction =  2.67% | cumulative = 18.85%
# cvPC  6: shared var = 1.145316 | fraction =  2.54% | cumulative = 21.39%
# cvPC  7: shared var = 1.078619 | fraction =  2.39% | cumulative = 23.78%
# cvPC  8: shared var = 1.029134 | fraction =  2.28% | cumulative = 26.06%
# cvPC  9: shared var = 0.953360 | fraction =  2.11% | cumulative = 28.18%
# cvPC 10: shared var = 0.886475 | fraction =  1.97% | cumulative = 30.14%
# cvPC 11: shared var = 0.854699 | fraction =  1.90% | cumulative = 32.04%
# cvPC 12: shared var = 0.828913 | fraction =  1.84% | cumulative = 33.88%
# cvPC 13: shared var = 0.823108 | fraction =  1.83% | cumulative = 35.70%
# cvPC 14: shared var = 0.784626 | fraction =  1.74% | cumulative = 37.44%
# cvPC 15: shared var = 0.739246 | fraction =  1.64% | cumulative = 39.08%
# cvPC 16: shared var = 0.739638 | fraction =  1.64% | cumulative = 40.72%
# cvPC 17: shared var = 0.686572 | fraction =  1.52% | cumulative = 42.25%
# cvPC 18: shared var = 0.663449 | fraction =  1.47% | cumulative = 43.72%
# cvPC 19: shared var = 0.644417 | fraction =  1.43% | cumulative = 45.15%
# cvPC 20: shared var = 0.622551 | fraction =  1.38% | cumulative = 46.53%
# cvPC 21: shared var = 0.601229 | fraction =  1.33% | cumulative = 47.86%
# cvPC 22: shared var = 0.584053 | fraction =  1.30% | cumulative = 49.16%
# cvPC 23: shared var = 0.587216 | fraction =  1.30% | cumulative = 50.46%
# cvPC 24: shared var = 0.581251 | fraction =  1.29% | cumulative = 51.75%
# cvPC 25: shared var = 0.562371 | fraction =  1.25% | cumulative = 53.00%
# cvPC 26: shared var = 0.536840 | fraction =  1.19% | cumulative = 54.19%
# cvPC 27: shared var = 0.537490 | fraction =  1.19% | cumulative = 55.38%
# cvPC 28: shared var = 0.513285 | fraction =  1.14% | cumulative = 56.52%
# cvPC 29: shared var = 0.502226 | fraction =  1.11% | cumulative = 57.63%
# cvPC 30: shared var = 0.488193 | fraction =  1.08% | cumulative = 58.72%
# cvPC 31: shared var = 0.485844 | fraction =  1.08% | cumulative = 59.79%
# cvPC 32: shared var = 0.485364 | fraction =  1.08% | cumulative = 60.87%
# cvPC 33: shared var = 0.453578 | fraction =  1.01% | cumulative = 61.88%
# cvPC 34: shared var = 0.460709 | fraction =  1.02% | cumulative = 62.90%
# cvPC 35: shared var = 0.445314 | fraction =  0.99% | cumulative = 63.89%
# cvPC 36: shared var = 0.451958 | fraction =  1.00% | cumulative = 64.89%
# cvPC 37: shared var = 0.422663 | fraction =  0.94% | cumulative = 65.83%
# cvPC 38: shared var = 0.432971 | fraction =  0.96% | cumulative = 66.79%
# cvPC 39: shared var = 0.422427 | fraction =  0.94% | cumulative = 67.72%
# cvPC 40: shared var = 0.411005 | fraction =  0.91% | cumulative = 68.64%
# cvPC 41: shared var = 0.414355 | fraction =  0.92% | cumulative = 69.56%
# cvPC 42: shared var = 0.399341 | fraction =  0.89% | cumulative = 70.44%
# cvPC 43: shared var = 0.399808 | fraction =  0.89% | cumulative = 71.33%
# cvPC 44: shared var = 0.397408 | fraction =  0.88% | cumulative = 72.21%
# cvPC 45: shared var = 0.384580 | fraction =  0.85% | cumulative = 73.06%
# cvPC 46: shared var = 0.372381 | fraction =  0.83% | cumulative = 73.89%
# cvPC 47: shared var = 0.382227 | fraction =  0.85% | cumulative = 74.74%
# cvPC 48: shared var = 0.368585 | fraction =  0.82% | cumulative = 75.55%
# cvPC 49: shared var = 0.366369 | fraction =  0.81% | cumulative = 76.37%
# cvPC 50: shared var = 0.361825 | fraction =  0.80% | cumulative = 77.17%
# cvPC 51: shared var = 0.359333 | fraction =  0.80% | cumulative = 77.97%
# cvPC 52: shared var = 0.361171 | fraction =  0.80% | cumulative = 78.77%
# cvPC 53: shared var = 0.345416 | fraction =  0.77% | cumulative = 79.53%
# cvPC 54: shared var = 0.345380 | fraction =  0.77% | cumulative = 80.30%
# cvPC 55: shared var = 0.339182 | fraction =  0.75% | cumulative = 81.05%
# cvPC 56: shared var = 0.332322 | fraction =  0.74% | cumulative = 81.79%
# cvPC 57: shared var = 0.321565 | fraction =  0.71% | cumulative = 82.50%
# cvPC 58: shared var = 0.319728 | fraction =  0.71% | cumulative = 83.21%
# cvPC 59: shared var = 0.323650 | fraction =  0.72% | cumulative = 83.93%
# cvPC 60: shared var = 0.308356 | fraction =  0.68% | cumulative = 84.61%
# cvPC 61: shared var = 0.310784 | fraction =  0.69% | cumulative = 85.30%
# cvPC 62: shared var = 0.307050 | fraction =  0.68% | cumulative = 85.99%
# cvPC 63: shared var = 0.295946 | fraction =  0.66% | cumulative = 86.64%
# cvPC 64: shared var = 0.287410 | fraction =  0.64% | cumulative = 87.28%
# cvPC 65: shared var = 0.290173 | fraction =  0.64% | cumulative = 87.92%
# cvPC 66: shared var = 0.289086 | fraction =  0.64% | cumulative = 88.56%
# cvPC 67: shared var = 0.282592 | fraction =  0.63% | cumulative = 89.19%
# cvPC 68: shared var = 0.271541 | fraction =  0.60% | cumulative = 89.79%
# cvPC 69: shared var = 0.269087 | fraction =  0.60% | cumulative = 90.39%
#
# ✅ Using first 69 cvPCA components as neural stimulus-locked basis in PCA space (covering 90.39% shared variance).
#
# 🔹 Cross-covariance SVD between ViT PCs and neural cvPCA scores...
# ===== Cross-covariance components (ViT ↔ neural cvPCA) =====
# Component  1: singular value = 14.475052 | cross-covariance fraction = 34.72%
# Component  2: singular value = 11.452232 | cross-covariance fraction = 21.73%
# Component  3: singular value = 5.750750 | cross-covariance fraction =  5.48%
# Component  4: singular value = 5.317426 | cross-covariance fraction =  4.69%
# Component  5: singular value = 5.137635 | cross-covariance fraction =  4.37%
# Component  6: singular value = 4.392598 | cross-covariance fraction =  3.20%
# Component  7: singular value = 4.190857 | cross-covariance fraction =  2.91%
# Component  8: singular value = 3.752160 | cross-covariance fraction =  2.33%
# Component  9: singular value = 3.548110 | cross-covariance fraction =  2.09%
# Component 10: singular value = 3.137437 | cross-covariance fraction =  1.63%
# Component 11: singular value = 2.953513 | cross-covariance fraction =  1.45%
# Component 12: singular value = 2.806647 | cross-covariance fraction =  1.31%
# Component 13: singular value = 2.685789 | cross-covariance fraction =  1.20%
# Component 14: singular value = 2.636443 | cross-covariance fraction =  1.15%
# Component 15: singular value = 2.499636 | cross-covariance fraction =  1.04%
# Component 16: singular value = 2.404752 | cross-covariance fraction =  0.96%
# Component 17: singular value = 2.230113 | cross-covariance fraction =  0.82%
# Component 18: singular value = 2.144278 | cross-covariance fraction =  0.76%
# Component 19: singular value = 2.110193 | cross-covariance fraction =  0.74%
# Component 20: singular value = 2.076406 | cross-covariance fraction =  0.71%
# Component 21: singular value = 2.006273 | cross-covariance fraction =  0.67%
# Component 22: singular value = 1.968855 | cross-covariance fraction =  0.64%
# Component 23: singular value = 1.872465 | cross-covariance fraction =  0.58%
# Component 24: singular value = 1.692914 | cross-covariance fraction =  0.47%
# Component 25: singular value = 1.612412 | cross-covariance fraction =  0.43%
# Component 26: singular value = 1.556409 | cross-covariance fraction =  0.40%
# Component 27: singular value = 1.477593 | cross-covariance fraction =  0.36%
# Component 28: singular value = 1.463079 | cross-covariance fraction =  0.35%
# Component 29: singular value = 1.411063 | cross-covariance fraction =  0.33%
# Component 30: singular value = 1.386888 | cross-covariance fraction =  0.32%
# Component 31: singular value = 1.350328 | cross-covariance fraction =  0.30%
# Component 32: singular value = 1.291778 | cross-covariance fraction =  0.28%
# Component 33: singular value = 1.265514 | cross-covariance fraction =  0.27%
# Component 34: singular value = 1.203039 | cross-covariance fraction =  0.24%
# Component 35: singular value = 1.136559 | cross-covariance fraction =  0.21%
# Component 36: singular value = 1.016999 | cross-covariance fraction =  0.17%
# Component 37: singular value = 0.989696 | cross-covariance fraction =  0.16%
# Component 38: singular value = 0.935910 | cross-covariance fraction =  0.15%
# Component 39: singular value = 0.798802 | cross-covariance fraction =  0.11%
# Component 40: singular value = 0.701782 | cross-covariance fraction =  0.08%
# Component 41: singular value = 0.672635 | cross-covariance fraction =  0.07%
# Component 42: singular value = 0.575559 | cross-covariance fraction =  0.05%
# Component 43: singular value = 0.468675 | cross-covariance fraction =  0.04%
# Component 44: singular value = 0.399443 | cross-covariance fraction =  0.03%
#
# 🔹 Variance explained in ORIGINAL neural PC data by cross-covariance components...
# ===== Neural PCA variance explained by cross-covariance components =====
# Cross-cov comp  1: explained var in neural PCA space =  4.33% | cumulative =  4.33%
# Cross-cov comp  2: explained var in neural PCA space =  2.58% | cumulative =  6.91%
# Cross-cov comp  3: explained var in neural PCA space =  2.71% | cumulative =  9.61%
# Cross-cov comp  4: explained var in neural PCA space =  1.68% | cumulative = 11.29%
# Cross-cov comp  5: explained var in neural PCA space =  2.30% | cumulative = 13.59%
# Cross-cov comp  6: explained var in neural PCA space =  2.17% | cumulative = 15.75%
# Cross-cov comp  7: explained var in neural PCA space =  1.45% | cumulative = 17.21%
# Cross-cov comp  8: explained var in neural PCA space =  1.39% | cumulative = 18.60%
# Cross-cov comp  9: explained var in neural PCA space =  1.78% | cumulative = 20.38%
# Cross-cov comp 10: explained var in neural PCA space =  1.53% | cumulative = 21.91%
# Cross-cov comp 11: explained var in neural PCA space =  1.59% | cumulative = 23.50%
# Cross-cov comp 12: explained var in neural PCA space =  1.54% | cumulative = 25.04%
# Cross-cov comp 13: explained var in neural PCA space =  1.62% | cumulative = 26.65%
# Cross-cov comp 14: explained var in neural PCA space =  1.65% | cumulative = 28.30%
# Cross-cov comp 15: explained var in neural PCA space =  1.59% | cumulative = 29.90%
# Cross-cov comp 16: explained var in neural PCA space =  1.24% | cumulative = 31.13%
# Cross-cov comp 17: explained var in neural PCA space =  1.40% | cumulative = 32.53%
# Cross-cov comp 18: explained var in neural PCA space =  1.25% | cumulative = 33.78%
# Cross-cov comp 19: explained var in neural PCA space =  1.38% | cumulative = 35.16%
# Cross-cov comp 20: explained var in neural PCA space =  1.22% | cumulative = 36.38%
# Cross-cov comp 21: explained var in neural PCA space =  1.43% | cumulative = 37.81%
# Cross-cov comp 22: explained var in neural PCA space =  1.58% | cumulative = 39.39%
# Cross-cov comp 23: explained var in neural PCA space =  1.40% | cumulative = 40.79%
# Cross-cov comp 24: explained var in neural PCA space =  1.34% | cumulative = 42.13%
# Cross-cov comp 25: explained var in neural PCA space =  1.11% | cumulative = 43.24%
# Cross-cov comp 26: explained var in neural PCA space =  1.10% | cumulative = 44.35%
# Cross-cov comp 27: explained var in neural PCA space =  1.04% | cumulative = 45.39%
# Cross-cov comp 28: explained var in neural PCA space =  1.27% | cumulative = 46.66%
# Cross-cov comp 29: explained var in neural PCA space =  1.13% | cumulative = 47.79%
# Cross-cov comp 30: explained var in neural PCA space =  1.13% | cumulative = 48.92%
# Cross-cov comp 31: explained var in neural PCA space =  0.98% | cumulative = 49.90%
# Cross-cov comp 32: explained var in neural PCA space =  1.35% | cumulative = 51.25%
# Cross-cov comp 33: explained var in neural PCA space =  1.07% | cumulative = 52.32%
# Cross-cov comp 34: explained var in neural PCA space =  1.21% | cumulative = 53.53%
# Cross-cov comp 35: explained var in neural PCA space =  1.11% | cumulative = 54.64%
# Cross-cov comp 36: explained var in neural PCA space =  1.17% | cumulative = 55.81%
# Cross-cov comp 37: explained var in neural PCA space =  1.19% | cumulative = 57.00%
# Cross-cov comp 38: explained var in neural PCA space =  1.06% | cumulative = 58.06%
# Cross-cov comp 39: explained var in neural PCA space =  1.07% | cumulative = 59.14%
# Cross-cov comp 40: explained var in neural PCA space =  1.23% | cumulative = 60.37%
# Cross-cov comp 41: explained var in neural PCA space =  1.15% | cumulative = 61.52%
# Cross-cov comp 42: explained var in neural PCA space =  1.08% | cumulative = 62.60%
# Cross-cov comp 43: explained var in neural PCA space =  1.05% | cumulative = 63.65%
# Cross-cov comp 44: explained var in neural PCA space =  1.03% | cumulative = 64.68%
#
# ✅ Total variance in ORIGINAL neural PC data accounted for (sum over all cross-cov comps): 64.68%
# 💾 Saved results to vit_VISp_pca_cvpca_crosscov_results.npz

# %%
#!/usr/bin/env python3
"""
Two-stage cvPCA pipeline with an initial PCA bottleneck:

1) ViT:
   - Softmax + CLR on logits for natural scenes
   - PCA → keep PCs up to VAR_CUTOFF variance

2) Neural:
   (a) Preprocess:
       - Load deconvolved responses
       - Select AREA_NAME
       - Reshape to (neurons × images × trials × time)
       - Compute stimulus-locked means
   (b) PCA on stimulus-locked means (all trials):
       - Xa = R_all.T  (images × neurons)
       - PCA → keep PCs up to VAR_CUTOFF variance
       - Get neural PC scores: Xa_pca (images × n_neural_pca)
   (c) cvPCA in neural PC space:
       - Split trials into even/odd → R_even, R_odd
       - Project to PCA space → Xe_pca, Xo_pca
       - cvPCA (Pachitariu-style) on these PC scores
       - Get neural cvPCA basis inside PCA space + shared variances
       - Get stimulus-locked neural cvPCA scores Zb_cv (images × n_cvpca)

3) Cross-covariance SVD:
   - Between ViT PC scores Zv and neural cvPCA scores Zb_cv
   - SVD of cross-covariance → shared directions U_cv, V_cv

4) Variance explained in original neural PC data:
   - Map cross-covariance components back into the original neural PCA space
   - Compute fraction of variance in Xa_pca explained by those components
"""

import numpy as np
import pickle
from sklearn.decomposition import PCA
from scipy.special import softmax
from skbio.stats.composition import clr

# ---------------------------------------------------------------
# CONFIG
# ---------------------------------------------------------------
VIT_PATH    = '/home/maria/Documents/HuggingMouseData/MouseViTEmbeddings/google_vit-base-patch16-224_embeddings_logits.pkl'
NEURAL_PATH = '/home/maria/LuckyMouse/pixel_transformer_neuro/data/processed/hybrid_neural_responses.npy'
AREAS_PATH  = '/home/maria/MITNeuralComputation/visualization/brain_area.npy'

AREA_NAME   = 'VISp'
AREA_NAME='VISrl'
N_IMAGES    = 118
N_TRIALS    = 50
VAR_CUTOFF  = 0.90
RANDOM_SEED = 42

rng = np.random.default_rng(RANDOM_SEED)

# ===============================================================
# STEP 1: ViT preprocessing (softmax + CLR + PCA)
# ===============================================================
print("🔹 Loading ViT embeddings...")
with open(VIT_PATH, 'rb') as f:
    vit_logits = pickle.load(f)['natural_scenes']  # (N_IMAGES × D_vit)

Xv = np.asarray(vit_logits)
Xv = softmax(Xv, axis=1)          # probabilities over classes
Xv = clr(Xv + 1e-12)              # CLR transform

print("🔹 PCA on ViT CLR embeddings...")
vit_pca_full = PCA(random_state=RANDOM_SEED).fit(Xv)
vit_cumvar = np.cumsum(vit_pca_full.explained_variance_ratio_)
vit_ncomp = np.searchsorted(vit_cumvar, VAR_CUTOFF) + 1

vit_pca = PCA(n_components=vit_ncomp, random_state=RANDOM_SEED)
Zv = vit_pca.fit_transform(Xv)    # (images × vit_ncomp)

print(f"✅ ViT PCs covering {VAR_CUTOFF*100:.0f}% variance: {vit_ncomp}")

# ===============================================================
# STEP 2: Neural preprocessing + FIRST PCA (to 90% var)
# ===============================================================
print(f"\n🔹 Loading neural responses, area = {AREA_NAME}...")
dat_all = np.load(NEURAL_PATH, mmap_mode='r')   # (n_neurons_total × (images*trials*time))
areas = np.load(AREAS_PATH, allow_pickle=True)  # (n_neurons_total,)

area_mask = (areas == AREA_NAME)
dat = dat_all[area_mask]                        # (n_neurons_area × n_total)
n_neurons, n_total = dat.shape

# Infer time bins
n_time = n_total // (N_IMAGES * N_TRIALS)
if N_IMAGES * N_TRIALS * n_time != n_total:
    raise ValueError(f"Inferred n_time={n_time} inconsistent with data shape.")

print(f"   → {n_neurons} neurons, n_total={n_total}, inferred n_time={n_time}")

# Reshape to (neurons × images × trials × time)
dat = dat.reshape(n_neurons, N_IMAGES, N_TRIALS, n_time)

# Stimulus-locked means:
# - R_even, R_odd: for cvPCA
# - R_all: all trials, for the initial PCA
even_idx = np.arange(0, N_TRIALS, 2)
odd_idx  = np.arange(1, N_TRIALS, 2)
print(f"   → Even trials: {even_idx.size}, odd trials: {odd_idx.size}")

R_even = dat[:, :, even_idx, :].mean(axis=(2, 3))   # (neurons × images)
R_odd  = dat[:, :, odd_idx,  :].mean(axis=(2, 3))   # (neurons × images)
R_all  = dat.mean(axis=(2, 3))                      # (neurons × images)

# For PCA: samples = images, features = neurons
Xa = R_all.T    # (images × neurons)
Xe = R_even.T   # (images × neurons)
Xo = R_odd.T    # (images × neurons)

print("\n🔹 FIRST PCA on stimulus-locked neural responses (all trials)...")
neural_pca_full = PCA(random_state=RANDOM_SEED).fit(Xa)
neural_cumvar = np.cumsum(neural_pca_full.explained_variance_ratio_)
neural_ncomp = np.searchsorted(neural_cumvar, VAR_CUTOFF) + 1

neural_pca = PCA(n_components=neural_ncomp, random_state=RANDOM_SEED)
Xa_pca = neural_pca.fit_transform(Xa)   # (images × neural_ncomp)
Xe_pca = neural_pca.transform(Xe)       # (images × neural_ncomp)
Xo_pca = neural_pca.transform(Xo)       # (images × neural_ncomp)

print(f"✅ Neural PCs (first stage) covering {VAR_CUTOFF*100:.0f}% variance: {neural_ncomp}")

# PCA basis in neuron space (neurons × neural_ncomp)
# sklearn: components_ is (n_components × n_features)
W_pca_neurons = neural_pca.components_.T

# ===============================================================
# STEP 3: cvPCA in neural PCA space
# ===============================================================
print("\n🔹 Running cvPCA on neural PCA scores (stimulus-locked)...")

n_stim = N_IMAGES

# Xe_pca and Xo_pca are already centered using the same mean in neuron space;
# we can treat them as zero-mean PC scores.
Xe0 = Xe_pca
Xo0 = Xo_pca

# Covariance of train (even) half in PCA space
Cb_pca = Xe0.T @ Xe0 / (n_stim - 1)      # (neural_ncomp × neural_ncomp)

# Eigen-decomposition in PCA space
eigvals, V_pca = np.linalg.eigh(Cb_pca)
idx = np.argsort(eigvals)[::-1]
eigvals = eigvals[idx]
V_pca = V_pca[:, idx]                    # (neural_ncomp × neural_ncomp)

# Project both halves onto these components (still in PCA space)
S1 = Xe0 @ V_pca                         # (images × neural_ncomp)
S2 = Xo0 @ V_pca                         # (images × neural_ncomp)

# Cross-validated variance per component
lam_cv = np.sum(S1 * S2, axis=0) / (n_stim - 1)   # (neural_ncomp,)

# Clamp negatives (noise)
lam_cv_pos = np.maximum(lam_cv, 0.0)
total_shared = lam_cv_pos.sum()
if total_shared <= 0:
    raise RuntimeError("Total shared variance (cvPCA) non-positive. Check data/splits.")

shared_frac = lam_cv_pos / total_shared
cum_shared_frac = np.cumsum(shared_frac)

# Pick number of cvPCA components by shared variance cutoff
brain_ncomp = np.searchsorted(cum_shared_frac, VAR_CUTOFF) + 1
brain_ncomp = min(brain_ncomp, V_pca.shape[1])

print("===== Neural cvPCA (in PCA space) =====")
for i in range(brain_ncomp):
    print(f"cvPC {i+1:2d}: shared var = {lam_cv_pos[i]:.6f} | "
          f"fraction = {shared_frac[i]*100:5.2f}% | "
          f"cumulative = {cum_shared_frac[i]*100:5.2f}%")

print(f"\n✅ Using first {brain_ncomp} cvPCA components as neural stimulus-locked basis "
      f"in PCA space (covering {cum_shared_frac[brain_ncomp-1]*100:.2f}% shared variance).")

# Neural cvPCA basis inside PCA space (neural_ncomp × brain_ncomp)
W_cvpca_pca = V_pca[:, :brain_ncomp]

# Now get neural cvPCA scores for ALL trials (Xa_pca) in this basis:
Zb_cv = Xa_pca @ W_cvpca_pca           # (images × brain_ncomp)

# Optionally, you can also get cvPCA basis back in neuron space:
# W_neural_cv = W_pca_neurons @ W_cvpca_pca   # (neurons × brain_ncomp)


# ===============================================================
# STEP 4: Cross-covariance between ViT PCs and neural cvPCA scores
# ===============================================================
print("\n🔹 Cross-covariance SVD between ViT PCs and neural cvPCA scores...")

# Center across images
Zv0 = Zv - Zv.mean(axis=0, keepdims=True)      # (images × vit_ncomp)
Zb0 = Zb_cv - Zb_cv.mean(axis=0, keepdims=True)  # (images × brain_ncomp)

# Cross-covariance
C_vb = (Zv0.T @ Zb0) / (n_stim - 1)            # (vit_ncomp × brain_ncomp)

# SVD of cross-covariance
U_cv, S_cv, Vt_cv = np.linalg.svd(C_vb, full_matrices=False)
V_cv = Vt_cv.T                                  # (brain_ncomp × r)

shared_cov_frac = (S_cv**2) / np.sum(S_cv**2)

print("===== Cross-covariance components (ViT ↔ neural cvPCA) =====")
for i, (s, frac) in enumerate(zip(S_cv, shared_cov_frac), start=1):
    print(f"Component {i:2d}: singular value = {s:.6f} | "
          f"cross-covariance fraction = {frac*100:5.2f}%")


# ===============================================================
# STEP 5: Variance explained in ORIGINAL neural PC data
#         by cross-covariance components
# ===============================================================
print("\n🔹 Variance explained in ORIGINAL neural PC data by cross-covariance components...")

# Original neural PC scores from FIRST PCA:
# Xa_pca: (images × neural_ncomp)
Xa_pca0 = Xa_pca - Xa_pca.mean(axis=0, keepdims=True)

# Total variance in original neural PCA space
total_var_neural_pca = np.sum(np.var(Xa_pca0, axis=0, ddof=1))

# Map cross-cov components from cvPCA space back into original neural PCA space:
# W_cvpca_pca: (neural_ncomp × brain_ncomp)
# V_cv:        (brain_ncomp × r)
# → B_pca:     (neural_ncomp × r), directions in original neural PCA space
B_pca = W_cvpca_pca @ V_cv                   # (neural_ncomp × r)

# Project original neural PC scores onto these cross-cov directions
Xb_cc_pca = Xa_pca0 @ B_pca                  # (images × r)

# Variance per cross-cov component in original neural PCA space
var_cc = np.var(Xb_cc_pca, axis=0, ddof=1)   # (r,)
frac_cc = var_cc / total_var_neural_pca
cum_frac_cc = np.cumsum(frac_cc)

print("===== Neural PCA variance explained by cross-covariance components =====")
for i, (f, cf) in enumerate(zip(frac_cc, cum_frac_cc), start=1):
    print(f"Cross-cov comp {i:2d}: "
          f"explained var in neural PCA space = {f*100:5.2f}% | "
          f"cumulative = {cf*100:5.2f}%")

print(f"\n✅ Total variance in ORIGINAL neural PC data accounted for "
      f"(sum over all cross-cov comps): {frac_cc.sum()*100:.2f}%")

# ===============================================================
# STEP 6: Save everything
# ===============================================================
out_name = f"vit_{AREA_NAME}_pca_cvpca_crosscov_results.npz"
np.savez(
    out_name,
    # ViT
    vit_scores=Zv,
    vit_basis=vit_pca.components_,
    vit_explained_var=vit_pca.explained_variance_ratio_,
    # Neural PCA
    neural_pca_scores=Xa_pca,
    neural_pca_basis=W_pca_neurons,
    neural_pca_explained_var=neural_pca.explained_variance_ratio_,
    # Neural cvPCA
    neural_cvpca_basis_pca=W_cvpca_pca,
    neural_cvpca_shared_var=lam_cv_pos[:brain_ncomp],
    neural_cvpca_shared_frac=shared_frac[:brain_ncomp],
    neural_cvpca_scores=Zb_cv,
    # Cross-covariance
    crosscov_matrix=C_vb,
    crosscov_singular_values=S_cv,
    crosscov_vit_basis=U_cv,
    crosscov_neural_cvpca_basis=V_cv,
    # Variance explained in ORIGINAL neural PCA space
    neural_pca_var_per_cc=var_cc,
    neural_pca_var_fraction_per_cc=frac_cc,
)

print(f"💾 Saved results to {out_name}")
# Out:
# 🔹 Loading ViT embeddings...
# 🔹 PCA on ViT CLR embeddings...
# ✅ ViT PCs covering 90% variance: 44
#
# 🔹 Loading neural responses, area = VISrl...
#    → 5444 neurons, n_total=5900, inferred n_time=1
#    → Even trials: 25, odd trials: 25
#
# 🔹 FIRST PCA on stimulus-locked neural responses (all trials)...
# ✅ Neural PCs (first stage) covering 90% variance: 97
#
# 🔹 Running cvPCA on neural PCA scores (stimulus-locked)...
# ===== Neural cvPCA (in PCA space) =====
# cvPC  1: shared var = 0.442530 | fraction = 10.48% | cumulative = 10.48%
# cvPC  2: shared var = 0.145514 | fraction =  3.44% | cumulative = 13.92%
# cvPC  3: shared var = 0.086204 | fraction =  2.04% | cumulative = 15.96%
# cvPC  4: shared var = 0.078553 | fraction =  1.86% | cumulative = 17.82%
# cvPC  5: shared var = 0.078648 | fraction =  1.86% | cumulative = 19.68%
# cvPC  6: shared var = 0.064578 | fraction =  1.53% | cumulative = 21.21%
# cvPC  7: shared var = 0.065306 | fraction =  1.55% | cumulative = 22.76%
# cvPC  8: shared var = 0.057476 | fraction =  1.36% | cumulative = 24.12%
# cvPC  9: shared var = 0.058377 | fraction =  1.38% | cumulative = 25.50%
# cvPC 10: shared var = 0.052784 | fraction =  1.25% | cumulative = 26.75%
# cvPC 11: shared var = 0.052478 | fraction =  1.24% | cumulative = 27.99%
# cvPC 12: shared var = 0.051218 | fraction =  1.21% | cumulative = 29.21%
# cvPC 13: shared var = 0.053747 | fraction =  1.27% | cumulative = 30.48%
# cvPC 14: shared var = 0.046642 | fraction =  1.10% | cumulative = 31.58%
# cvPC 15: shared var = 0.047108 | fraction =  1.12% | cumulative = 32.70%
# cvPC 16: shared var = 0.047486 | fraction =  1.12% | cumulative = 33.82%
# cvPC 17: shared var = 0.043807 | fraction =  1.04% | cumulative = 34.86%
# cvPC 18: shared var = 0.044933 | fraction =  1.06% | cumulative = 35.92%
# cvPC 19: shared var = 0.046678 | fraction =  1.11% | cumulative = 37.03%
# cvPC 20: shared var = 0.042279 | fraction =  1.00% | cumulative = 38.03%
# cvPC 21: shared var = 0.045066 | fraction =  1.07% | cumulative = 39.10%
# cvPC 22: shared var = 0.042607 | fraction =  1.01% | cumulative = 40.10%
# cvPC 23: shared var = 0.042231 | fraction =  1.00% | cumulative = 41.10%
# cvPC 24: shared var = 0.041383 | fraction =  0.98% | cumulative = 42.08%
# cvPC 25: shared var = 0.039432 | fraction =  0.93% | cumulative = 43.02%
# cvPC 26: shared var = 0.042226 | fraction =  1.00% | cumulative = 44.02%
# cvPC 27: shared var = 0.039866 | fraction =  0.94% | cumulative = 44.96%
# cvPC 28: shared var = 0.039582 | fraction =  0.94% | cumulative = 45.90%
# cvPC 29: shared var = 0.040799 | fraction =  0.97% | cumulative = 46.86%
# cvPC 30: shared var = 0.039487 | fraction =  0.93% | cumulative = 47.80%
# cvPC 31: shared var = 0.041965 | fraction =  0.99% | cumulative = 48.79%
# cvPC 32: shared var = 0.037969 | fraction =  0.90% | cumulative = 49.69%
# cvPC 33: shared var = 0.038817 | fraction =  0.92% | cumulative = 50.61%
# cvPC 34: shared var = 0.039693 | fraction =  0.94% | cumulative = 51.55%
# cvPC 35: shared var = 0.038328 | fraction =  0.91% | cumulative = 52.46%
# cvPC 36: shared var = 0.036359 | fraction =  0.86% | cumulative = 53.32%
# cvPC 37: shared var = 0.038671 | fraction =  0.92% | cumulative = 54.23%
# cvPC 38: shared var = 0.037276 | fraction =  0.88% | cumulative = 55.12%
# cvPC 39: shared var = 0.037419 | fraction =  0.89% | cumulative = 56.00%
# cvPC 40: shared var = 0.037810 | fraction =  0.90% | cumulative = 56.90%
# cvPC 41: shared var = 0.036515 | fraction =  0.86% | cumulative = 57.76%
# cvPC 42: shared var = 0.035853 | fraction =  0.85% | cumulative = 58.61%
# cvPC 43: shared var = 0.035047 | fraction =  0.83% | cumulative = 59.44%
# cvPC 44: shared var = 0.037305 | fraction =  0.88% | cumulative = 60.32%
# cvPC 45: shared var = 0.034181 | fraction =  0.81% | cumulative = 61.13%
# cvPC 46: shared var = 0.035605 | fraction =  0.84% | cumulative = 61.97%
# cvPC 47: shared var = 0.037246 | fraction =  0.88% | cumulative = 62.86%
# cvPC 48: shared var = 0.034508 | fraction =  0.82% | cumulative = 63.67%
# cvPC 49: shared var = 0.034524 | fraction =  0.82% | cumulative = 64.49%
# cvPC 50: shared var = 0.034946 | fraction =  0.83% | cumulative = 65.32%
# cvPC 51: shared var = 0.034287 | fraction =  0.81% | cumulative = 66.13%
# cvPC 52: shared var = 0.034494 | fraction =  0.82% | cumulative = 66.95%
# cvPC 53: shared var = 0.034758 | fraction =  0.82% | cumulative = 67.77%
# cvPC 54: shared var = 0.034096 | fraction =  0.81% | cumulative = 68.58%
# cvPC 55: shared var = 0.032861 | fraction =  0.78% | cumulative = 69.35%
# cvPC 56: shared var = 0.033375 | fraction =  0.79% | cumulative = 70.14%
# cvPC 57: shared var = 0.034847 | fraction =  0.82% | cumulative = 70.97%
# cvPC 58: shared var = 0.034120 | fraction =  0.81% | cumulative = 71.78%
# cvPC 59: shared var = 0.033130 | fraction =  0.78% | cumulative = 72.56%
# cvPC 60: shared var = 0.033421 | fraction =  0.79% | cumulative = 73.35%
# cvPC 61: shared var = 0.033383 | fraction =  0.79% | cumulative = 74.14%
# cvPC 62: shared var = 0.033291 | fraction =  0.79% | cumulative = 74.93%
# cvPC 63: shared var = 0.032626 | fraction =  0.77% | cumulative = 75.70%
# cvPC 64: shared var = 0.032896 | fraction =  0.78% | cumulative = 76.48%
# cvPC 65: shared var = 0.032095 | fraction =  0.76% | cumulative = 77.24%
# cvPC 66: shared var = 0.031949 | fraction =  0.76% | cumulative = 78.00%
# cvPC 67: shared var = 0.031698 | fraction =  0.75% | cumulative = 78.75%
# cvPC 68: shared var = 0.031939 | fraction =  0.76% | cumulative = 79.50%
# cvPC 69: shared var = 0.032121 | fraction =  0.76% | cumulative = 80.27%
# cvPC 70: shared var = 0.031197 | fraction =  0.74% | cumulative = 81.00%
# cvPC 71: shared var = 0.030557 | fraction =  0.72% | cumulative = 81.73%
# cvPC 72: shared var = 0.031983 | fraction =  0.76% | cumulative = 82.48%
# cvPC 73: shared var = 0.031172 | fraction =  0.74% | cumulative = 83.22%
# cvPC 74: shared var = 0.031156 | fraction =  0.74% | cumulative = 83.96%
# cvPC 75: shared var = 0.031594 | fraction =  0.75% | cumulative = 84.71%
# cvPC 76: shared var = 0.030923 | fraction =  0.73% | cumulative = 85.44%
# cvPC 77: shared var = 0.030898 | fraction =  0.73% | cumulative = 86.17%
# cvPC 78: shared var = 0.031084 | fraction =  0.74% | cumulative = 86.91%
# cvPC 79: shared var = 0.030390 | fraction =  0.72% | cumulative = 87.63%
# cvPC 80: shared var = 0.031180 | fraction =  0.74% | cumulative = 88.36%
# cvPC 81: shared var = 0.029397 | fraction =  0.70% | cumulative = 89.06%
# cvPC 82: shared var = 0.029040 | fraction =  0.69% | cumulative = 89.75%
# cvPC 83: shared var = 0.030752 | fraction =  0.73% | cumulative = 90.48%
#
# ✅ Using first 83 cvPCA components as neural stimulus-locked basis in PCA space (covering 90.48% shared variance).
#
# 🔹 Cross-covariance SVD between ViT PCs and neural cvPCA scores...
# ===== Cross-covariance components (ViT ↔ neural cvPCA) =====
# Component  1: singular value = 4.331931 | cross-covariance fraction = 36.38%
# Component  2: singular value = 2.798246 | cross-covariance fraction = 15.18%
# Component  3: singular value = 2.042524 | cross-covariance fraction =  8.09%
# Component  4: singular value = 1.660808 | cross-covariance fraction =  5.35%
# Component  5: singular value = 1.516000 | cross-covariance fraction =  4.46%
# Component  6: singular value = 1.262703 | cross-covariance fraction =  3.09%
# Component  7: singular value = 1.174967 | cross-covariance fraction =  2.68%
# Component  8: singular value = 1.031385 | cross-covariance fraction =  2.06%
# Component  9: singular value = 1.004962 | cross-covariance fraction =  1.96%
# Component 10: singular value = 0.942868 | cross-covariance fraction =  1.72%
# Component 11: singular value = 0.896259 | cross-covariance fraction =  1.56%
# Component 12: singular value = 0.827432 | cross-covariance fraction =  1.33%
# Component 13: singular value = 0.814059 | cross-covariance fraction =  1.28%
# Component 14: singular value = 0.769596 | cross-covariance fraction =  1.15%
# Component 15: singular value = 0.739973 | cross-covariance fraction =  1.06%
# Component 16: singular value = 0.708071 | cross-covariance fraction =  0.97%
# Component 17: singular value = 0.674483 | cross-covariance fraction =  0.88%
# Component 18: singular value = 0.652341 | cross-covariance fraction =  0.82%
# Component 19: singular value = 0.638333 | cross-covariance fraction =  0.79%
# Component 20: singular value = 0.614693 | cross-covariance fraction =  0.73%
# Component 21: singular value = 0.576458 | cross-covariance fraction =  0.64%
# Component 22: singular value = 0.558804 | cross-covariance fraction =  0.61%
# Component 23: singular value = 0.551135 | cross-covariance fraction =  0.59%
# Component 24: singular value = 0.531970 | cross-covariance fraction =  0.55%
# Component 25: singular value = 0.523078 | cross-covariance fraction =  0.53%
# Component 26: singular value = 0.516040 | cross-covariance fraction =  0.52%
# Component 27: singular value = 0.503104 | cross-covariance fraction =  0.49%
# Component 28: singular value = 0.477948 | cross-covariance fraction =  0.44%
# Component 29: singular value = 0.464830 | cross-covariance fraction =  0.42%
# Component 30: singular value = 0.460451 | cross-covariance fraction =  0.41%
# Component 31: singular value = 0.446903 | cross-covariance fraction =  0.39%
# Component 32: singular value = 0.424128 | cross-covariance fraction =  0.35%
# Component 33: singular value = 0.413433 | cross-covariance fraction =  0.33%
# Component 34: singular value = 0.402685 | cross-covariance fraction =  0.31%
# Component 35: singular value = 0.386554 | cross-covariance fraction =  0.29%
# Component 36: singular value = 0.378747 | cross-covariance fraction =  0.28%
# Component 37: singular value = 0.365018 | cross-covariance fraction =  0.26%
# Component 38: singular value = 0.346998 | cross-covariance fraction =  0.23%
# Component 39: singular value = 0.326525 | cross-covariance fraction =  0.21%
# Component 40: singular value = 0.326033 | cross-covariance fraction =  0.21%
# Component 41: singular value = 0.274143 | cross-covariance fraction =  0.15%
# Component 42: singular value = 0.250735 | cross-covariance fraction =  0.12%
# Component 43: singular value = 0.211761 | cross-covariance fraction =  0.09%
# Component 44: singular value = 0.181045 | cross-covariance fraction =  0.06%
#
# 🔹 Variance explained in ORIGINAL neural PC data by cross-covariance components...
# ===== Neural PCA variance explained by cross-covariance components =====
# Cross-cov comp  1: explained var in neural PCA space =  4.94% | cumulative =  4.94%
# Cross-cov comp  2: explained var in neural PCA space =  1.89% | cumulative =  6.84%
# Cross-cov comp  3: explained var in neural PCA space =  4.46% | cumulative = 11.30%
# Cross-cov comp  4: explained var in neural PCA space =  1.54% | cumulative = 12.83%
# Cross-cov comp  5: explained var in neural PCA space =  1.26% | cumulative = 14.10%
# Cross-cov comp  6: explained var in neural PCA space =  1.09% | cumulative = 15.18%
# Cross-cov comp  7: explained var in neural PCA space =  1.33% | cumulative = 16.51%
# Cross-cov comp  8: explained var in neural PCA space =  1.03% | cumulative = 17.55%
# Cross-cov comp  9: explained var in neural PCA space =  0.99% | cumulative = 18.54%
# Cross-cov comp 10: explained var in neural PCA space =  1.20% | cumulative = 19.74%
# Cross-cov comp 11: explained var in neural PCA space =  1.14% | cumulative = 20.87%
# Cross-cov comp 12: explained var in neural PCA space =  1.08% | cumulative = 21.96%
# Cross-cov comp 13: explained var in neural PCA space =  1.25% | cumulative = 23.20%
# Cross-cov comp 14: explained var in neural PCA space =  1.23% | cumulative = 24.44%
# Cross-cov comp 15: explained var in neural PCA space =  1.15% | cumulative = 25.59%
# Cross-cov comp 16: explained var in neural PCA space =  1.19% | cumulative = 26.78%
# Cross-cov comp 17: explained var in neural PCA space =  1.06% | cumulative = 27.84%
# Cross-cov comp 18: explained var in neural PCA space =  0.97% | cumulative = 28.81%
# Cross-cov comp 19: explained var in neural PCA space =  0.97% | cumulative = 29.78%
# Cross-cov comp 20: explained var in neural PCA space =  0.99% | cumulative = 30.77%
# Cross-cov comp 21: explained var in neural PCA space =  0.95% | cumulative = 31.73%
# Cross-cov comp 22: explained var in neural PCA space =  1.05% | cumulative = 32.78%
# Cross-cov comp 23: explained var in neural PCA space =  1.04% | cumulative = 33.82%
# Cross-cov comp 24: explained var in neural PCA space =  1.09% | cumulative = 34.91%
# Cross-cov comp 25: explained var in neural PCA space =  0.97% | cumulative = 35.88%
# Cross-cov comp 26: explained var in neural PCA space =  0.96% | cumulative = 36.84%
# Cross-cov comp 27: explained var in neural PCA space =  0.97% | cumulative = 37.81%
# Cross-cov comp 28: explained var in neural PCA space =  0.95% | cumulative = 38.77%
# Cross-cov comp 29: explained var in neural PCA space =  0.95% | cumulative = 39.72%
# Cross-cov comp 30: explained var in neural PCA space =  0.99% | cumulative = 40.71%
# Cross-cov comp 31: explained var in neural PCA space =  0.97% | cumulative = 41.67%
# Cross-cov comp 32: explained var in neural PCA space =  0.92% | cumulative = 42.60%
# Cross-cov comp 33: explained var in neural PCA space =  1.10% | cumulative = 43.69%
# Cross-cov comp 34: explained var in neural PCA space =  0.98% | cumulative = 44.67%
# Cross-cov comp 35: explained var in neural PCA space =  0.86% | cumulative = 45.54%
# Cross-cov comp 36: explained var in neural PCA space =  0.96% | cumulative = 46.50%
# Cross-cov comp 37: explained var in neural PCA space =  0.89% | cumulative = 47.38%
# Cross-cov comp 38: explained var in neural PCA space =  1.10% | cumulative = 48.48%
# Cross-cov comp 39: explained var in neural PCA space =  0.94% | cumulative = 49.42%
# Cross-cov comp 40: explained var in neural PCA space =  1.10% | cumulative = 50.51%
# Cross-cov comp 41: explained var in neural PCA space =  0.96% | cumulative = 51.48%
# Cross-cov comp 42: explained var in neural PCA space =  0.88% | cumulative = 52.36%
# Cross-cov comp 43: explained var in neural PCA space =  0.88% | cumulative = 53.24%
# Cross-cov comp 44: explained var in neural PCA space =  0.92% | cumulative = 54.16%
#
# ✅ Total variance in ORIGINAL neural PC data accounted for (sum over all cross-cov comps): 54.16%
# 💾 Saved results to vit_VISrl_pca_cvpca_crosscov_results.npz

# %%
#!/usr/bin/env python3
"""
Two-stage cvPCA pipeline with an initial PCA bottleneck:

1) ViT:
   - Softmax + CLR on logits for natural scenes
   - PCA → keep PCs up to VAR_CUTOFF variance

2) Neural:
   (a) Preprocess:
       - Load deconvolved responses
       - Select AREA_NAME
       - Reshape to (neurons × images × trials × time)
       - Compute stimulus-locked means
   (b) PCA on stimulus-locked means (all trials):
       - Xa = R_all.T  (images × neurons)
       - PCA → keep PCs up to VAR_CUTOFF variance
       - Get neural PC scores: Xa_pca (images × n_neural_pca)
   (c) cvPCA in neural PC space:
       - Split trials into even/odd → R_even, R_odd
       - Project to PCA space → Xe_pca, Xo_pca
       - cvPCA (Pachitariu-style) on these PC scores
       - Get neural cvPCA basis inside PCA space + shared variances
       - Get stimulus-locked neural cvPCA scores Zb_cv (images × n_cvpca)

3) Cross-covariance SVD:
   - Between ViT PC scores Zv and neural cvPCA scores Zb_cv
   - SVD of cross-covariance → shared directions U_cv, V_cv

4) Variance explained in original neural PC data:
   - Map cross-covariance components back into the original neural PCA space
   - Compute fraction of variance in Xa_pca explained by those components
"""

import numpy as np
import pickle
from sklearn.decomposition import PCA
from scipy.special import softmax
from skbio.stats.composition import clr

# ---------------------------------------------------------------
# CONFIG
# ---------------------------------------------------------------
VIT_PATH    = '/home/maria/Documents/HuggingMouseData/MouseViTEmbeddings/google_vit-base-patch16-224_embeddings_logits.pkl'
NEURAL_PATH = '/home/maria/LuckyMouse/pixel_transformer_neuro/data/processed/hybrid_neural_responses.npy'
AREAS_PATH  = '/home/maria/MITNeuralComputation/visualization/brain_area.npy'

AREA_NAME   = 'VISp'
AREA_NAME='VISal'
N_IMAGES    = 118
N_TRIALS    = 50
VAR_CUTOFF  = 0.90
RANDOM_SEED = 42

rng = np.random.default_rng(RANDOM_SEED)

# ===============================================================
# STEP 1: ViT preprocessing (softmax + CLR + PCA)
# ===============================================================
print("🔹 Loading ViT embeddings...")
with open(VIT_PATH, 'rb') as f:
    vit_logits = pickle.load(f)['natural_scenes']  # (N_IMAGES × D_vit)

Xv = np.asarray(vit_logits)
Xv = softmax(Xv, axis=1)          # probabilities over classes
Xv = clr(Xv + 1e-12)              # CLR transform

print("🔹 PCA on ViT CLR embeddings...")
vit_pca_full = PCA(random_state=RANDOM_SEED).fit(Xv)
vit_cumvar = np.cumsum(vit_pca_full.explained_variance_ratio_)
vit_ncomp = np.searchsorted(vit_cumvar, VAR_CUTOFF) + 1

vit_pca = PCA(n_components=vit_ncomp, random_state=RANDOM_SEED)
Zv = vit_pca.fit_transform(Xv)    # (images × vit_ncomp)

print(f"✅ ViT PCs covering {VAR_CUTOFF*100:.0f}% variance: {vit_ncomp}")

# ===============================================================
# STEP 2: Neural preprocessing + FIRST PCA (to 90% var)
# ===============================================================
print(f"\n🔹 Loading neural responses, area = {AREA_NAME}...")
dat_all = np.load(NEURAL_PATH, mmap_mode='r')   # (n_neurons_total × (images*trials*time))
areas = np.load(AREAS_PATH, allow_pickle=True)  # (n_neurons_total,)

area_mask = (areas == AREA_NAME)
dat = dat_all[area_mask]                        # (n_neurons_area × n_total)
n_neurons, n_total = dat.shape

# Infer time bins
n_time = n_total // (N_IMAGES * N_TRIALS)
if N_IMAGES * N_TRIALS * n_time != n_total:
    raise ValueError(f"Inferred n_time={n_time} inconsistent with data shape.")

print(f"   → {n_neurons} neurons, n_total={n_total}, inferred n_time={n_time}")

# Reshape to (neurons × images × trials × time)
dat = dat.reshape(n_neurons, N_IMAGES, N_TRIALS, n_time)

# Stimulus-locked means:
# - R_even, R_odd: for cvPCA
# - R_all: all trials, for the initial PCA
even_idx = np.arange(0, N_TRIALS, 2)
odd_idx  = np.arange(1, N_TRIALS, 2)
print(f"   → Even trials: {even_idx.size}, odd trials: {odd_idx.size}")

R_even = dat[:, :, even_idx, :].mean(axis=(2, 3))   # (neurons × images)
R_odd  = dat[:, :, odd_idx,  :].mean(axis=(2, 3))   # (neurons × images)
R_all  = dat.mean(axis=(2, 3))                      # (neurons × images)

# For PCA: samples = images, features = neurons
Xa = R_all.T    # (images × neurons)
Xe = R_even.T   # (images × neurons)
Xo = R_odd.T    # (images × neurons)

print("\n🔹 FIRST PCA on stimulus-locked neural responses (all trials)...")
neural_pca_full = PCA(random_state=RANDOM_SEED).fit(Xa)
neural_cumvar = np.cumsum(neural_pca_full.explained_variance_ratio_)
neural_ncomp = np.searchsorted(neural_cumvar, VAR_CUTOFF) + 1

neural_pca = PCA(n_components=neural_ncomp, random_state=RANDOM_SEED)
Xa_pca = neural_pca.fit_transform(Xa)   # (images × neural_ncomp)
Xe_pca = neural_pca.transform(Xe)       # (images × neural_ncomp)
Xo_pca = neural_pca.transform(Xo)       # (images × neural_ncomp)

print(f"✅ Neural PCs (first stage) covering {VAR_CUTOFF*100:.0f}% variance: {neural_ncomp}")

# PCA basis in neuron space (neurons × neural_ncomp)
# sklearn: components_ is (n_components × n_features)
W_pca_neurons = neural_pca.components_.T

# ===============================================================
# STEP 3: cvPCA in neural PCA space
# ===============================================================
print("\n🔹 Running cvPCA on neural PCA scores (stimulus-locked)...")

n_stim = N_IMAGES

# Xe_pca and Xo_pca are already centered using the same mean in neuron space;
# we can treat them as zero-mean PC scores.
Xe0 = Xe_pca
Xo0 = Xo_pca

# Covariance of train (even) half in PCA space
Cb_pca = Xe0.T @ Xe0 / (n_stim - 1)      # (neural_ncomp × neural_ncomp)

# Eigen-decomposition in PCA space
eigvals, V_pca = np.linalg.eigh(Cb_pca)
idx = np.argsort(eigvals)[::-1]
eigvals = eigvals[idx]
V_pca = V_pca[:, idx]                    # (neural_ncomp × neural_ncomp)

# Project both halves onto these components (still in PCA space)
S1 = Xe0 @ V_pca                         # (images × neural_ncomp)
S2 = Xo0 @ V_pca                         # (images × neural_ncomp)

# Cross-validated variance per component
lam_cv = np.sum(S1 * S2, axis=0) / (n_stim - 1)   # (neural_ncomp,)

# Clamp negatives (noise)
lam_cv_pos = np.maximum(lam_cv, 0.0)
total_shared = lam_cv_pos.sum()
if total_shared <= 0:
    raise RuntimeError("Total shared variance (cvPCA) non-positive. Check data/splits.")

shared_frac = lam_cv_pos / total_shared
cum_shared_frac = np.cumsum(shared_frac)

# Pick number of cvPCA components by shared variance cutoff
brain_ncomp = np.searchsorted(cum_shared_frac, VAR_CUTOFF) + 1
brain_ncomp = min(brain_ncomp, V_pca.shape[1])

print("===== Neural cvPCA (in PCA space) =====")
for i in range(brain_ncomp):
    print(f"cvPC {i+1:2d}: shared var = {lam_cv_pos[i]:.6f} | "
          f"fraction = {shared_frac[i]*100:5.2f}% | "
          f"cumulative = {cum_shared_frac[i]*100:5.2f}%")

print(f"\n✅ Using first {brain_ncomp} cvPCA components as neural stimulus-locked basis "
      f"in PCA space (covering {cum_shared_frac[brain_ncomp-1]*100:.2f}% shared variance).")

# Neural cvPCA basis inside PCA space (neural_ncomp × brain_ncomp)
W_cvpca_pca = V_pca[:, :brain_ncomp]

# Now get neural cvPCA scores for ALL trials (Xa_pca) in this basis:
Zb_cv = Xa_pca @ W_cvpca_pca           # (images × brain_ncomp)

# Optionally, you can also get cvPCA basis back in neuron space:
# W_neural_cv = W_pca_neurons @ W_cvpca_pca   # (neurons × brain_ncomp)


# ===============================================================
# STEP 4: Cross-covariance between ViT PCs and neural cvPCA scores
# ===============================================================
print("\n🔹 Cross-covariance SVD between ViT PCs and neural cvPCA scores...")

# Center across images
Zv0 = Zv - Zv.mean(axis=0, keepdims=True)      # (images × vit_ncomp)
Zb0 = Zb_cv - Zb_cv.mean(axis=0, keepdims=True)  # (images × brain_ncomp)

# Cross-covariance
C_vb = (Zv0.T @ Zb0) / (n_stim - 1)            # (vit_ncomp × brain_ncomp)

# SVD of cross-covariance
U_cv, S_cv, Vt_cv = np.linalg.svd(C_vb, full_matrices=False)
V_cv = Vt_cv.T                                  # (brain_ncomp × r)

shared_cov_frac = (S_cv**2) / np.sum(S_cv**2)

print("===== Cross-covariance components (ViT ↔ neural cvPCA) =====")
for i, (s, frac) in enumerate(zip(S_cv, shared_cov_frac), start=1):
    print(f"Component {i:2d}: singular value = {s:.6f} | "
          f"cross-covariance fraction = {frac*100:5.2f}%")


# ===============================================================
# STEP 5: Variance explained in ORIGINAL neural PC data
#         by cross-covariance components
# ===============================================================
print("\n🔹 Variance explained in ORIGINAL neural PC data by cross-covariance components...")

# Original neural PC scores from FIRST PCA:
# Xa_pca: (images × neural_ncomp)
Xa_pca0 = Xa_pca - Xa_pca.mean(axis=0, keepdims=True)

# Total variance in original neural PCA space
total_var_neural_pca = np.sum(np.var(Xa_pca0, axis=0, ddof=1))

# Map cross-cov components from cvPCA space back into original neural PCA space:
# W_cvpca_pca: (neural_ncomp × brain_ncomp)
# V_cv:        (brain_ncomp × r)
# → B_pca:     (neural_ncomp × r), directions in original neural PCA space
B_pca = W_cvpca_pca @ V_cv                   # (neural_ncomp × r)

# Project original neural PC scores onto these cross-cov directions
Xb_cc_pca = Xa_pca0 @ B_pca                  # (images × r)

# Variance per cross-cov component in original neural PCA space
var_cc = np.var(Xb_cc_pca, axis=0, ddof=1)   # (r,)
frac_cc = var_cc / total_var_neural_pca
cum_frac_cc = np.cumsum(frac_cc)

print("===== Neural PCA variance explained by cross-covariance components =====")
for i, (f, cf) in enumerate(zip(frac_cc, cum_frac_cc), start=1):
    print(f"Cross-cov comp {i:2d}: "
          f"explained var in neural PCA space = {f*100:5.2f}% | "
          f"cumulative = {cf*100:5.2f}%")

print(f"\n✅ Total variance in ORIGINAL neural PC data accounted for "
      f"(sum over all cross-cov comps): {frac_cc.sum()*100:.2f}%")

# ===============================================================
# STEP 6: Save everything
# ===============================================================
out_name = f"vit_{AREA_NAME}_pca_cvpca_crosscov_results.npz"
np.savez(
    out_name,
    # ViT
    vit_scores=Zv,
    vit_basis=vit_pca.components_,
    vit_explained_var=vit_pca.explained_variance_ratio_,
    # Neural PCA
    neural_pca_scores=Xa_pca,
    neural_pca_basis=W_pca_neurons,
    neural_pca_explained_var=neural_pca.explained_variance_ratio_,
    # Neural cvPCA
    neural_cvpca_basis_pca=W_cvpca_pca,
    neural_cvpca_shared_var=lam_cv_pos[:brain_ncomp],
    neural_cvpca_shared_frac=shared_frac[:brain_ncomp],
    neural_cvpca_scores=Zb_cv,
    # Cross-covariance
    crosscov_matrix=C_vb,
    crosscov_singular_values=S_cv,
    crosscov_vit_basis=U_cv,
    crosscov_neural_cvpca_basis=V_cv,
    # Variance explained in ORIGINAL neural PCA space
    neural_pca_var_per_cc=var_cc,
    neural_pca_var_fraction_per_cc=frac_cc,
)

print(f"💾 Saved results to {out_name}")
# Out:
# 🔹 Loading ViT embeddings...
# 🔹 PCA on ViT CLR embeddings...
# ✅ ViT PCs covering 90% variance: 44
#
# 🔹 Loading neural responses, area = VISal...
#    → 4249 neurons, n_total=5900, inferred n_time=1
#    → Even trials: 25, odd trials: 25
#
# 🔹 FIRST PCA on stimulus-locked neural responses (all trials)...
# ✅ Neural PCs (first stage) covering 90% variance: 78
#
# 🔹 Running cvPCA on neural PCA scores (stimulus-locked)...
# ===== Neural cvPCA (in PCA space) =====
# cvPC  1: shared var = 0.974171 | fraction =  8.78% | cumulative =  8.78%
# cvPC  2: shared var = 0.717318 | fraction =  6.46% | cumulative = 15.24%
# cvPC  3: shared var = 0.477984 | fraction =  4.31% | cumulative = 19.55%
# cvPC  4: shared var = 0.440635 | fraction =  3.97% | cumulative = 23.52%
# cvPC  5: shared var = 0.412276 | fraction =  3.72% | cumulative = 27.24%
# cvPC  6: shared var = 0.356162 | fraction =  3.21% | cumulative = 30.45%
# cvPC  7: shared var = 0.327304 | fraction =  2.95% | cumulative = 33.40%
# cvPC  8: shared var = 0.278704 | fraction =  2.51% | cumulative = 35.91%
# cvPC  9: shared var = 0.273115 | fraction =  2.46% | cumulative = 38.37%
# cvPC 10: shared var = 0.263697 | fraction =  2.38% | cumulative = 40.75%
# cvPC 11: shared var = 0.250398 | fraction =  2.26% | cumulative = 43.00%
# cvPC 12: shared var = 0.240932 | fraction =  2.17% | cumulative = 45.17%
# cvPC 13: shared var = 0.230285 | fraction =  2.08% | cumulative = 47.25%
# cvPC 14: shared var = 0.201484 | fraction =  1.82% | cumulative = 49.07%
# cvPC 15: shared var = 0.189955 | fraction =  1.71% | cumulative = 50.78%
# cvPC 16: shared var = 0.185575 | fraction =  1.67% | cumulative = 52.45%
# cvPC 17: shared var = 0.179787 | fraction =  1.62% | cumulative = 54.07%
# cvPC 18: shared var = 0.166547 | fraction =  1.50% | cumulative = 55.57%
# cvPC 19: shared var = 0.158147 | fraction =  1.43% | cumulative = 57.00%
# cvPC 20: shared var = 0.146421 | fraction =  1.32% | cumulative = 58.32%
# cvPC 21: shared var = 0.141452 | fraction =  1.27% | cumulative = 59.59%
# cvPC 22: shared var = 0.138981 | fraction =  1.25% | cumulative = 60.84%
# cvPC 23: shared var = 0.131685 | fraction =  1.19% | cumulative = 62.03%
# cvPC 24: shared var = 0.136300 | fraction =  1.23% | cumulative = 63.26%
# cvPC 25: shared var = 0.135034 | fraction =  1.22% | cumulative = 64.48%
# cvPC 26: shared var = 0.125656 | fraction =  1.13% | cumulative = 65.61%
# cvPC 27: shared var = 0.121705 | fraction =  1.10% | cumulative = 66.70%
# cvPC 28: shared var = 0.119362 | fraction =  1.08% | cumulative = 67.78%
# cvPC 29: shared var = 0.112443 | fraction =  1.01% | cumulative = 68.79%
# cvPC 30: shared var = 0.111589 | fraction =  1.01% | cumulative = 69.80%
# cvPC 31: shared var = 0.107965 | fraction =  0.97% | cumulative = 70.77%
# cvPC 32: shared var = 0.102541 | fraction =  0.92% | cumulative = 71.70%
# cvPC 33: shared var = 0.100366 | fraction =  0.90% | cumulative = 72.60%
# cvPC 34: shared var = 0.103000 | fraction =  0.93% | cumulative = 73.53%
# cvPC 35: shared var = 0.097800 | fraction =  0.88% | cumulative = 74.41%
# cvPC 36: shared var = 0.095607 | fraction =  0.86% | cumulative = 75.27%
# cvPC 37: shared var = 0.090500 | fraction =  0.82% | cumulative = 76.09%
# cvPC 38: shared var = 0.090322 | fraction =  0.81% | cumulative = 76.90%
# cvPC 39: shared var = 0.088393 | fraction =  0.80% | cumulative = 77.70%
# cvPC 40: shared var = 0.087436 | fraction =  0.79% | cumulative = 78.49%
# cvPC 41: shared var = 0.089012 | fraction =  0.80% | cumulative = 79.29%
# cvPC 42: shared var = 0.088317 | fraction =  0.80% | cumulative = 80.08%
# cvPC 43: shared var = 0.081054 | fraction =  0.73% | cumulative = 80.81%
# cvPC 44: shared var = 0.077702 | fraction =  0.70% | cumulative = 81.51%
# cvPC 45: shared var = 0.077757 | fraction =  0.70% | cumulative = 82.22%
# cvPC 46: shared var = 0.078490 | fraction =  0.71% | cumulative = 82.92%
# cvPC 47: shared var = 0.078205 | fraction =  0.70% | cumulative = 83.63%
# cvPC 48: shared var = 0.074141 | fraction =  0.67% | cumulative = 84.30%
# cvPC 49: shared var = 0.074151 | fraction =  0.67% | cumulative = 84.96%
# cvPC 50: shared var = 0.073618 | fraction =  0.66% | cumulative = 85.63%
# cvPC 51: shared var = 0.073142 | fraction =  0.66% | cumulative = 86.29%
# cvPC 52: shared var = 0.066824 | fraction =  0.60% | cumulative = 86.89%
# cvPC 53: shared var = 0.068569 | fraction =  0.62% | cumulative = 87.51%
# cvPC 54: shared var = 0.069178 | fraction =  0.62% | cumulative = 88.13%
# cvPC 55: shared var = 0.065572 | fraction =  0.59% | cumulative = 88.72%
# cvPC 56: shared var = 0.064551 | fraction =  0.58% | cumulative = 89.30%
# cvPC 57: shared var = 0.066831 | fraction =  0.60% | cumulative = 89.91%
# cvPC 58: shared var = 0.064670 | fraction =  0.58% | cumulative = 90.49%
#
# ✅ Using first 58 cvPCA components as neural stimulus-locked basis in PCA space (covering 90.49% shared variance).
#
# 🔹 Cross-covariance SVD between ViT PCs and neural cvPCA scores...
# ===== Cross-covariance components (ViT ↔ neural cvPCA) =====
# Component  1: singular value = 7.570440 | cross-covariance fraction = 36.07%
# Component  2: singular value = 5.909077 | cross-covariance fraction = 21.98%
# Component  3: singular value = 3.308205 | cross-covariance fraction =  6.89%
# Component  4: singular value = 2.990697 | cross-covariance fraction =  5.63%
# Component  5: singular value = 2.427938 | cross-covariance fraction =  3.71%
# Component  6: singular value = 2.261765 | cross-covariance fraction =  3.22%
# Component  7: singular value = 2.175154 | cross-covariance fraction =  2.98%
# Component  8: singular value = 1.930326 | cross-covariance fraction =  2.35%
# Component  9: singular value = 1.829542 | cross-covariance fraction =  2.11%
# Component 10: singular value = 1.564931 | cross-covariance fraction =  1.54%
# Component 11: singular value = 1.435833 | cross-covariance fraction =  1.30%
# Component 12: singular value = 1.356933 | cross-covariance fraction =  1.16%
# Component 13: singular value = 1.307259 | cross-covariance fraction =  1.08%
# Component 14: singular value = 1.235971 | cross-covariance fraction =  0.96%
# Component 15: singular value = 1.201092 | cross-covariance fraction =  0.91%
# Component 16: singular value = 1.120501 | cross-covariance fraction =  0.79%
# Component 17: singular value = 1.026972 | cross-covariance fraction =  0.66%
# Component 18: singular value = 1.011212 | cross-covariance fraction =  0.64%
# Component 19: singular value = 0.965406 | cross-covariance fraction =  0.59%
# Component 20: singular value = 0.917475 | cross-covariance fraction =  0.53%
# Component 21: singular value = 0.915702 | cross-covariance fraction =  0.53%
# Component 22: singular value = 0.864833 | cross-covariance fraction =  0.47%
# Component 23: singular value = 0.829117 | cross-covariance fraction =  0.43%
# Component 24: singular value = 0.801121 | cross-covariance fraction =  0.40%
# Component 25: singular value = 0.766425 | cross-covariance fraction =  0.37%
# Component 26: singular value = 0.716150 | cross-covariance fraction =  0.32%
# Component 27: singular value = 0.674896 | cross-covariance fraction =  0.29%
# Component 28: singular value = 0.672296 | cross-covariance fraction =  0.28%
# Component 29: singular value = 0.627608 | cross-covariance fraction =  0.25%
# Component 30: singular value = 0.581707 | cross-covariance fraction =  0.21%
# Component 31: singular value = 0.558809 | cross-covariance fraction =  0.20%
# Component 32: singular value = 0.553322 | cross-covariance fraction =  0.19%
# Component 33: singular value = 0.538557 | cross-covariance fraction =  0.18%
# Component 34: singular value = 0.476651 | cross-covariance fraction =  0.14%
# Component 35: singular value = 0.458841 | cross-covariance fraction =  0.13%
# Component 36: singular value = 0.398515 | cross-covariance fraction =  0.10%
# Component 37: singular value = 0.383819 | cross-covariance fraction =  0.09%
# Component 38: singular value = 0.361888 | cross-covariance fraction =  0.08%
# Component 39: singular value = 0.327684 | cross-covariance fraction =  0.07%
# Component 40: singular value = 0.302530 | cross-covariance fraction =  0.06%
# Component 41: singular value = 0.255894 | cross-covariance fraction =  0.04%
# Component 42: singular value = 0.234919 | cross-covariance fraction =  0.03%
# Component 43: singular value = 0.169674 | cross-covariance fraction =  0.02%
# Component 44: singular value = 0.146944 | cross-covariance fraction =  0.01%
#
# 🔹 Variance explained in ORIGINAL neural PC data by cross-covariance components...
# ===== Neural PCA variance explained by cross-covariance components =====
# Cross-cov comp  1: explained var in neural PCA space =  4.28% | cumulative =  4.28%
# Cross-cov comp  2: explained var in neural PCA space =  5.24% | cumulative =  9.52%
# Cross-cov comp  3: explained var in neural PCA space =  3.53% | cumulative = 13.05%
# Cross-cov comp  4: explained var in neural PCA space =  3.01% | cumulative = 16.07%
# Cross-cov comp  5: explained var in neural PCA space =  2.57% | cumulative = 18.64%
# Cross-cov comp  6: explained var in neural PCA space =  3.20% | cumulative = 21.84%
# Cross-cov comp  7: explained var in neural PCA space =  3.24% | cumulative = 25.08%
# Cross-cov comp  8: explained var in neural PCA space =  2.48% | cumulative = 27.56%
# Cross-cov comp  9: explained var in neural PCA space =  1.91% | cumulative = 29.47%
# Cross-cov comp 10: explained var in neural PCA space =  1.60% | cumulative = 31.07%
# Cross-cov comp 11: explained var in neural PCA space =  1.64% | cumulative = 32.71%
# Cross-cov comp 12: explained var in neural PCA space =  2.19% | cumulative = 34.90%
# Cross-cov comp 13: explained var in neural PCA space =  1.80% | cumulative = 36.70%
# Cross-cov comp 14: explained var in neural PCA space =  1.40% | cumulative = 38.11%
# Cross-cov comp 15: explained var in neural PCA space =  1.80% | cumulative = 39.91%
# Cross-cov comp 16: explained var in neural PCA space =  1.58% | cumulative = 41.49%
# Cross-cov comp 17: explained var in neural PCA space =  1.58% | cumulative = 43.07%
# Cross-cov comp 18: explained var in neural PCA space =  1.70% | cumulative = 44.77%
# Cross-cov comp 19: explained var in neural PCA space =  1.90% | cumulative = 46.68%
# Cross-cov comp 20: explained var in neural PCA space =  1.62% | cumulative = 48.30%
# Cross-cov comp 21: explained var in neural PCA space =  1.58% | cumulative = 49.88%
# Cross-cov comp 22: explained var in neural PCA space =  1.45% | cumulative = 51.32%
# Cross-cov comp 23: explained var in neural PCA space =  1.22% | cumulative = 52.55%
# Cross-cov comp 24: explained var in neural PCA space =  1.00% | cumulative = 53.55%
# Cross-cov comp 25: explained var in neural PCA space =  1.20% | cumulative = 54.75%
# Cross-cov comp 26: explained var in neural PCA space =  1.13% | cumulative = 55.88%
# Cross-cov comp 27: explained var in neural PCA space =  1.08% | cumulative = 56.96%
# Cross-cov comp 28: explained var in neural PCA space =  1.28% | cumulative = 58.24%
# Cross-cov comp 29: explained var in neural PCA space =  1.14% | cumulative = 59.38%
# Cross-cov comp 30: explained var in neural PCA space =  1.19% | cumulative = 60.56%
# Cross-cov comp 31: explained var in neural PCA space =  1.13% | cumulative = 61.69%
# Cross-cov comp 32: explained var in neural PCA space =  1.15% | cumulative = 62.84%
# Cross-cov comp 33: explained var in neural PCA space =  1.43% | cumulative = 64.28%
# Cross-cov comp 34: explained var in neural PCA space =  1.18% | cumulative = 65.46%
# Cross-cov comp 35: explained var in neural PCA space =  1.16% | cumulative = 66.62%
# Cross-cov comp 36: explained var in neural PCA space =  1.29% | cumulative = 67.91%
# Cross-cov comp 37: explained var in neural PCA space =  0.95% | cumulative = 68.86%
# Cross-cov comp 38: explained var in neural PCA space =  0.96% | cumulative = 69.82%
# Cross-cov comp 39: explained var in neural PCA space =  1.02% | cumulative = 70.84%
# Cross-cov comp 40: explained var in neural PCA space =  1.03% | cumulative = 71.86%
# Cross-cov comp 41: explained var in neural PCA space =  0.98% | cumulative = 72.84%
# Cross-cov comp 42: explained var in neural PCA space =  1.08% | cumulative = 73.92%
# Cross-cov comp 43: explained var in neural PCA space =  0.83% | cumulative = 74.76%
# Cross-cov comp 44: explained var in neural PCA space =  1.11% | cumulative = 75.86%
#
# ✅ Total variance in ORIGINAL neural PC data accounted for (sum over all cross-cov comps): 75.86%
# 💾 Saved results to vit_VISal_pca_cvpca_crosscov_results.npz

# %%
#!/usr/bin/env python3
"""
Two-stage cvPCA pipeline with an initial PCA bottleneck:

1) ViT:
   - Softmax + CLR on logits for natural scenes
   - PCA → keep PCs up to VAR_CUTOFF variance

2) Neural:
   (a) Preprocess:
       - Load deconvolved responses
       - Select AREA_NAME
       - Reshape to (neurons × images × trials × time)
       - Compute stimulus-locked means
   (b) PCA on stimulus-locked means (all trials):
       - Xa = R_all.T  (images × neurons)
       - PCA → keep PCs up to VAR_CUTOFF variance
       - Get neural PC scores: Xa_pca (images × n_neural_pca)
   (c) cvPCA in neural PC space:
       - Split trials into even/odd → R_even, R_odd
       - Project to PCA space → Xe_pca, Xo_pca
       - cvPCA (Pachitariu-style) on these PC scores
       - Get neural cvPCA basis inside PCA space + shared variances
       - Get stimulus-locked neural cvPCA scores Zb_cv (images × n_cvpca)

3) Cross-covariance SVD:
   - Between ViT PC scores Zv and neural cvPCA scores Zb_cv
   - SVD of cross-covariance → shared directions U_cv, V_cv

4) Variance explained in original neural PC data:
   - Map cross-covariance components back into the original neural PCA space
   - Compute fraction of variance in Xa_pca explained by those components
"""

import numpy as np
import pickle
from sklearn.decomposition import PCA
from scipy.special import softmax
from skbio.stats.composition import clr

# ---------------------------------------------------------------
# CONFIG
# ---------------------------------------------------------------
VIT_PATH    = '/home/maria/Documents/HuggingMouseData/MouseViTEmbeddings/google_vit-base-patch16-224_embeddings_logits.pkl'
NEURAL_PATH = '/home/maria/LuckyMouse/pixel_transformer_neuro/data/processed/hybrid_neural_responses.npy'
AREAS_PATH  = '/home/maria/MITNeuralComputation/visualization/brain_area.npy'

AREA_NAME   = 'VISp'
AREA_NAME='VISrl'
AREA_NAME='VISal'
AREA_NAME='VISl'
N_IMAGES    = 118
N_TRIALS    = 50
VAR_CUTOFF  = 0.90
RANDOM_SEED = 42

rng = np.random.default_rng(RANDOM_SEED)

# ===============================================================
# STEP 1: ViT preprocessing (softmax + CLR + PCA)
# ===============================================================
print("🔹 Loading ViT embeddings...")
with open(VIT_PATH, 'rb') as f:
    vit_logits = pickle.load(f)['natural_scenes']  # (N_IMAGES × D_vit)

Xv = np.asarray(vit_logits)
Xv = softmax(Xv, axis=1)          # probabilities over classes
Xv = clr(Xv + 1e-12)              # CLR transform

print("🔹 PCA on ViT CLR embeddings...")
vit_pca_full = PCA(random_state=RANDOM_SEED).fit(Xv)
vit_cumvar = np.cumsum(vit_pca_full.explained_variance_ratio_)
vit_ncomp = np.searchsorted(vit_cumvar, VAR_CUTOFF) + 1

vit_pca = PCA(n_components=vit_ncomp, random_state=RANDOM_SEED)
Zv = vit_pca.fit_transform(Xv)    # (images × vit_ncomp)

print(f"✅ ViT PCs covering {VAR_CUTOFF*100:.0f}% variance: {vit_ncomp}")

# ===============================================================
# STEP 2: Neural preprocessing + FIRST PCA (to 90% var)
# ===============================================================
print(f"\n🔹 Loading neural responses, area = {AREA_NAME}...")
dat_all = np.load(NEURAL_PATH, mmap_mode='r')   # (n_neurons_total × (images*trials*time))
areas = np.load(AREAS_PATH, allow_pickle=True)  # (n_neurons_total,)

area_mask = (areas == AREA_NAME)
dat = dat_all[area_mask]                        # (n_neurons_area × n_total)
n_neurons, n_total = dat.shape

# Infer time bins
n_time = n_total // (N_IMAGES * N_TRIALS)
if N_IMAGES * N_TRIALS * n_time != n_total:
    raise ValueError(f"Inferred n_time={n_time} inconsistent with data shape.")

print(f"   → {n_neurons} neurons, n_total={n_total}, inferred n_time={n_time}")

# Reshape to (neurons × images × trials × time)
dat = dat.reshape(n_neurons, N_IMAGES, N_TRIALS, n_time)

# Stimulus-locked means:
# - R_even, R_odd: for cvPCA
# - R_all: all trials, for the initial PCA
even_idx = np.arange(0, N_TRIALS, 2)
odd_idx  = np.arange(1, N_TRIALS, 2)
print(f"   → Even trials: {even_idx.size}, odd trials: {odd_idx.size}")

R_even = dat[:, :, even_idx, :].mean(axis=(2, 3))   # (neurons × images)
R_odd  = dat[:, :, odd_idx,  :].mean(axis=(2, 3))   # (neurons × images)
R_all  = dat.mean(axis=(2, 3))                      # (neurons × images)

# For PCA: samples = images, features = neurons
Xa = R_all.T    # (images × neurons)
Xe = R_even.T   # (images × neurons)
Xo = R_odd.T    # (images × neurons)

print("\n🔹 FIRST PCA on stimulus-locked neural responses (all trials)...")
neural_pca_full = PCA(random_state=RANDOM_SEED).fit(Xa)
neural_cumvar = np.cumsum(neural_pca_full.explained_variance_ratio_)
neural_ncomp = np.searchsorted(neural_cumvar, VAR_CUTOFF) + 1

neural_pca = PCA(n_components=neural_ncomp, random_state=RANDOM_SEED)
Xa_pca = neural_pca.fit_transform(Xa)   # (images × neural_ncomp)
Xe_pca = neural_pca.transform(Xe)       # (images × neural_ncomp)
Xo_pca = neural_pca.transform(Xo)       # (images × neural_ncomp)

print(f"✅ Neural PCs (first stage) covering {VAR_CUTOFF*100:.0f}% variance: {neural_ncomp}")

# PCA basis in neuron space (neurons × neural_ncomp)
# sklearn: components_ is (n_components × n_features)
W_pca_neurons = neural_pca.components_.T

# ===============================================================
# STEP 3: cvPCA in neural PCA space
# ===============================================================
print("\n🔹 Running cvPCA on neural PCA scores (stimulus-locked)...")

n_stim = N_IMAGES

# Xe_pca and Xo_pca are already centered using the same mean in neuron space;
# we can treat them as zero-mean PC scores.
Xe0 = Xe_pca
Xo0 = Xo_pca

# Covariance of train (even) half in PCA space
Cb_pca = Xe0.T @ Xe0 / (n_stim - 1)      # (neural_ncomp × neural_ncomp)

# Eigen-decomposition in PCA space
eigvals, V_pca = np.linalg.eigh(Cb_pca)
idx = np.argsort(eigvals)[::-1]
eigvals = eigvals[idx]
V_pca = V_pca[:, idx]                    # (neural_ncomp × neural_ncomp)

# Project both halves onto these components (still in PCA space)
S1 = Xe0 @ V_pca                         # (images × neural_ncomp)
S2 = Xo0 @ V_pca                         # (images × neural_ncomp)

# Cross-validated variance per component
lam_cv = np.sum(S1 * S2, axis=0) / (n_stim - 1)   # (neural_ncomp,)

# Clamp negatives (noise)
lam_cv_pos = np.maximum(lam_cv, 0.0)
total_shared = lam_cv_pos.sum()
if total_shared <= 0:
    raise RuntimeError("Total shared variance (cvPCA) non-positive. Check data/splits.")

shared_frac = lam_cv_pos / total_shared
cum_shared_frac = np.cumsum(shared_frac)

# Pick number of cvPCA components by shared variance cutoff
brain_ncomp = np.searchsorted(cum_shared_frac, VAR_CUTOFF) + 1
brain_ncomp = min(brain_ncomp, V_pca.shape[1])

print("===== Neural cvPCA (in PCA space) =====")
for i in range(brain_ncomp):
    print(f"cvPC {i+1:2d}: shared var = {lam_cv_pos[i]:.6f} | "
          f"fraction = {shared_frac[i]*100:5.2f}% | "
          f"cumulative = {cum_shared_frac[i]*100:5.2f}%")

print(f"\n✅ Using first {brain_ncomp} cvPCA components as neural stimulus-locked basis "
      f"in PCA space (covering {cum_shared_frac[brain_ncomp-1]*100:.2f}% shared variance).")

# Neural cvPCA basis inside PCA space (neural_ncomp × brain_ncomp)
W_cvpca_pca = V_pca[:, :brain_ncomp]

# Now get neural cvPCA scores for ALL trials (Xa_pca) in this basis:
Zb_cv = Xa_pca @ W_cvpca_pca           # (images × brain_ncomp)

# Optionally, you can also get cvPCA basis back in neuron space:
# W_neural_cv = W_pca_neurons @ W_cvpca_pca   # (neurons × brain_ncomp)


# ===============================================================
# STEP 4: Cross-covariance between ViT PCs and neural cvPCA scores
# ===============================================================
print("\n🔹 Cross-covariance SVD between ViT PCs and neural cvPCA scores...")

# Center across images
Zv0 = Zv - Zv.mean(axis=0, keepdims=True)      # (images × vit_ncomp)
Zb0 = Zb_cv - Zb_cv.mean(axis=0, keepdims=True)  # (images × brain_ncomp)

# Cross-covariance
C_vb = (Zv0.T @ Zb0) / (n_stim - 1)            # (vit_ncomp × brain_ncomp)

# SVD of cross-covariance
U_cv, S_cv, Vt_cv = np.linalg.svd(C_vb, full_matrices=False)
V_cv = Vt_cv.T                                  # (brain_ncomp × r)

shared_cov_frac = (S_cv**2) / np.sum(S_cv**2)

print("===== Cross-covariance components (ViT ↔ neural cvPCA) =====")
for i, (s, frac) in enumerate(zip(S_cv, shared_cov_frac), start=1):
    print(f"Component {i:2d}: singular value = {s:.6f} | "
          f"cross-covariance fraction = {frac*100:5.2f}%")


# ===============================================================
# STEP 5: Variance explained in ORIGINAL neural PC data
#         by cross-covariance components
# ===============================================================
print("\n🔹 Variance explained in ORIGINAL neural PC data by cross-covariance components...")

# Original neural PC scores from FIRST PCA:
# Xa_pca: (images × neural_ncomp)
Xa_pca0 = Xa_pca - Xa_pca.mean(axis=0, keepdims=True)

# Total variance in original neural PCA space
total_var_neural_pca = np.sum(np.var(Xa_pca0, axis=0, ddof=1))

# Map cross-cov components from cvPCA space back into original neural PCA space:
# W_cvpca_pca: (neural_ncomp × brain_ncomp)
# V_cv:        (brain_ncomp × r)
# → B_pca:     (neural_ncomp × r), directions in original neural PCA space
B_pca = W_cvpca_pca @ V_cv                   # (neural_ncomp × r)

# Project original neural PC scores onto these cross-cov directions
Xb_cc_pca = Xa_pca0 @ B_pca                  # (images × r)

# Variance per cross-cov component in original neural PCA space
var_cc = np.var(Xb_cc_pca, axis=0, ddof=1)   # (r,)
frac_cc = var_cc / total_var_neural_pca
cum_frac_cc = np.cumsum(frac_cc)

print("===== Neural PCA variance explained by cross-covariance components =====")
for i, (f, cf) in enumerate(zip(frac_cc, cum_frac_cc), start=1):
    print(f"Cross-cov comp {i:2d}: "
          f"explained var in neural PCA space = {f*100:5.2f}% | "
          f"cumulative = {cf*100:5.2f}%")

print(f"\n✅ Total variance in ORIGINAL neural PC data accounted for "
      f"(sum over all cross-cov comps): {frac_cc.sum()*100:.2f}%")

# ===============================================================
# STEP 6: Save everything
# ===============================================================
out_name = f"vit_{AREA_NAME}_pca_cvpca_crosscov_results.npz"
np.savez(
    out_name,
    # ViT
    vit_scores=Zv,
    vit_basis=vit_pca.components_,
    vit_explained_var=vit_pca.explained_variance_ratio_,
    # Neural PCA
    neural_pca_scores=Xa_pca,
    neural_pca_basis=W_pca_neurons,
    neural_pca_explained_var=neural_pca.explained_variance_ratio_,
    # Neural cvPCA
    neural_cvpca_basis_pca=W_cvpca_pca,
    neural_cvpca_shared_var=lam_cv_pos[:brain_ncomp],
    neural_cvpca_shared_frac=shared_frac[:brain_ncomp],
    neural_cvpca_scores=Zb_cv,
    # Cross-covariance
    crosscov_matrix=C_vb,
    crosscov_singular_values=S_cv,
    crosscov_vit_basis=U_cv,
    crosscov_neural_cvpca_basis=V_cv,
    # Variance explained in ORIGINAL neural PCA space
    neural_pca_var_per_cc=var_cc,
    neural_pca_var_fraction_per_cc=frac_cc,
)

print(f"💾 Saved results to {out_name}")
# Out:
# 🔹 Loading ViT embeddings...
# 🔹 PCA on ViT CLR embeddings...
# ✅ ViT PCs covering 90% variance: 44
#
# 🔹 Loading neural responses, area = VISl...
#    → 8323 neurons, n_total=5900, inferred n_time=1
#    → Even trials: 25, odd trials: 25
#
# 🔹 FIRST PCA on stimulus-locked neural responses (all trials)...
# ✅ Neural PCs (first stage) covering 90% variance: 83
#
# 🔹 Running cvPCA on neural PCA scores (stimulus-locked)...
# ===== Neural cvPCA (in PCA space) =====
# cvPC  1: shared var = 1.799642 | fraction =  6.46% | cumulative =  6.46%
# cvPC  2: shared var = 1.239985 | fraction =  4.45% | cumulative = 10.91%
# cvPC  3: shared var = 1.200263 | fraction =  4.31% | cumulative = 15.22%
# cvPC  4: shared var = 0.930263 | fraction =  3.34% | cumulative = 18.56%
# cvPC  5: shared var = 0.927909 | fraction =  3.33% | cumulative = 21.89%
# cvPC  6: shared var = 0.790907 | fraction =  2.84% | cumulative = 24.72%
# cvPC  7: shared var = 0.723772 | fraction =  2.60% | cumulative = 27.32%
# cvPC  8: shared var = 0.686440 | fraction =  2.46% | cumulative = 29.79%
# cvPC  9: shared var = 0.682859 | fraction =  2.45% | cumulative = 32.24%
# cvPC 10: shared var = 0.595042 | fraction =  2.14% | cumulative = 34.37%
# cvPC 11: shared var = 0.540978 | fraction =  1.94% | cumulative = 36.31%
# cvPC 12: shared var = 0.526360 | fraction =  1.89% | cumulative = 38.20%
# cvPC 13: shared var = 0.519575 | fraction =  1.86% | cumulative = 40.07%
# cvPC 14: shared var = 0.473797 | fraction =  1.70% | cumulative = 41.77%
# cvPC 15: shared var = 0.452004 | fraction =  1.62% | cumulative = 43.39%
# cvPC 16: shared var = 0.433607 | fraction =  1.56% | cumulative = 44.95%
# cvPC 17: shared var = 0.431357 | fraction =  1.55% | cumulative = 46.49%
# cvPC 18: shared var = 0.416971 | fraction =  1.50% | cumulative = 47.99%
# cvPC 19: shared var = 0.410783 | fraction =  1.47% | cumulative = 49.47%
# cvPC 20: shared var = 0.395967 | fraction =  1.42% | cumulative = 50.89%
# cvPC 21: shared var = 0.375612 | fraction =  1.35% | cumulative = 52.23%
# cvPC 22: shared var = 0.370504 | fraction =  1.33% | cumulative = 53.56%
# cvPC 23: shared var = 0.367345 | fraction =  1.32% | cumulative = 54.88%
# cvPC 24: shared var = 0.360140 | fraction =  1.29% | cumulative = 56.18%
# cvPC 25: shared var = 0.325457 | fraction =  1.17% | cumulative = 57.34%
# cvPC 26: shared var = 0.321786 | fraction =  1.15% | cumulative = 58.50%
# cvPC 27: shared var = 0.318985 | fraction =  1.14% | cumulative = 59.64%
# cvPC 28: shared var = 0.327692 | fraction =  1.18% | cumulative = 60.82%
# cvPC 29: shared var = 0.303045 | fraction =  1.09% | cumulative = 61.91%
# cvPC 30: shared var = 0.305570 | fraction =  1.10% | cumulative = 63.00%
# cvPC 31: shared var = 0.306168 | fraction =  1.10% | cumulative = 64.10%
# cvPC 32: shared var = 0.286935 | fraction =  1.03% | cumulative = 65.13%
# cvPC 33: shared var = 0.284672 | fraction =  1.02% | cumulative = 66.15%
# cvPC 34: shared var = 0.280818 | fraction =  1.01% | cumulative = 67.16%
# cvPC 35: shared var = 0.265715 | fraction =  0.95% | cumulative = 68.12%
# cvPC 36: shared var = 0.268495 | fraction =  0.96% | cumulative = 69.08%
# cvPC 37: shared var = 0.264713 | fraction =  0.95% | cumulative = 70.03%
# cvPC 38: shared var = 0.263347 | fraction =  0.95% | cumulative = 70.97%
# cvPC 39: shared var = 0.250418 | fraction =  0.90% | cumulative = 71.87%
# cvPC 40: shared var = 0.252036 | fraction =  0.90% | cumulative = 72.78%
# cvPC 41: shared var = 0.243946 | fraction =  0.88% | cumulative = 73.65%
# cvPC 42: shared var = 0.237559 | fraction =  0.85% | cumulative = 74.51%
# cvPC 43: shared var = 0.233129 | fraction =  0.84% | cumulative = 75.34%
# cvPC 44: shared var = 0.235820 | fraction =  0.85% | cumulative = 76.19%
# cvPC 45: shared var = 0.225171 | fraction =  0.81% | cumulative = 77.00%
# cvPC 46: shared var = 0.216362 | fraction =  0.78% | cumulative = 77.77%
# cvPC 47: shared var = 0.219770 | fraction =  0.79% | cumulative = 78.56%
# cvPC 48: shared var = 0.211110 | fraction =  0.76% | cumulative = 79.32%
# cvPC 49: shared var = 0.212283 | fraction =  0.76% | cumulative = 80.08%
# cvPC 50: shared var = 0.207282 | fraction =  0.74% | cumulative = 80.83%
# cvPC 51: shared var = 0.204585 | fraction =  0.73% | cumulative = 81.56%
# cvPC 52: shared var = 0.207802 | fraction =  0.75% | cumulative = 82.31%
# cvPC 53: shared var = 0.200561 | fraction =  0.72% | cumulative = 83.03%
# cvPC 54: shared var = 0.194872 | fraction =  0.70% | cumulative = 83.73%
# cvPC 55: shared var = 0.198960 | fraction =  0.71% | cumulative = 84.44%
# cvPC 56: shared var = 0.193112 | fraction =  0.69% | cumulative = 85.13%
# cvPC 57: shared var = 0.185592 | fraction =  0.67% | cumulative = 85.80%
# cvPC 58: shared var = 0.185371 | fraction =  0.67% | cumulative = 86.46%
# cvPC 59: shared var = 0.183842 | fraction =  0.66% | cumulative = 87.12%
# cvPC 60: shared var = 0.179822 | fraction =  0.65% | cumulative = 87.77%
# cvPC 61: shared var = 0.176230 | fraction =  0.63% | cumulative = 88.40%
# cvPC 62: shared var = 0.175230 | fraction =  0.63% | cumulative = 89.03%
# cvPC 63: shared var = 0.175543 | fraction =  0.63% | cumulative = 89.66%
# cvPC 64: shared var = 0.172957 | fraction =  0.62% | cumulative = 90.28%
#
# ✅ Using first 64 cvPCA components as neural stimulus-locked basis in PCA space (covering 90.28% shared variance).
#
# 🔹 Cross-covariance SVD between ViT PCs and neural cvPCA scores...
# ===== Cross-covariance components (ViT ↔ neural cvPCA) =====
# Component  1: singular value = 12.014092 | cross-covariance fraction = 36.97%
# Component  2: singular value = 8.838399 | cross-covariance fraction = 20.01%
# Component  3: singular value = 4.925834 | cross-covariance fraction =  6.21%
# Component  4: singular value = 4.450688 | cross-covariance fraction =  5.07%
# Component  5: singular value = 4.152136 | cross-covariance fraction =  4.42%
# Component  6: singular value = 3.600879 | cross-covariance fraction =  3.32%
# Component  7: singular value = 3.207705 | cross-covariance fraction =  2.64%
# Component  8: singular value = 3.097342 | cross-covariance fraction =  2.46%
# Component  9: singular value = 2.890932 | cross-covariance fraction =  2.14%
# Component 10: singular value = 2.537373 | cross-covariance fraction =  1.65%
# Component 11: singular value = 2.425907 | cross-covariance fraction =  1.51%
# Component 12: singular value = 2.262088 | cross-covariance fraction =  1.31%
# Component 13: singular value = 2.164982 | cross-covariance fraction =  1.20%
# Component 14: singular value = 2.025374 | cross-covariance fraction =  1.05%
# Component 15: singular value = 1.948242 | cross-covariance fraction =  0.97%
# Component 16: singular value = 1.878006 | cross-covariance fraction =  0.90%
# Component 17: singular value = 1.703547 | cross-covariance fraction =  0.74%
# Component 18: singular value = 1.621910 | cross-covariance fraction =  0.67%
# Component 19: singular value = 1.554299 | cross-covariance fraction =  0.62%
# Component 20: singular value = 1.539971 | cross-covariance fraction =  0.61%
# Component 21: singular value = 1.443592 | cross-covariance fraction =  0.53%
# Component 22: singular value = 1.395832 | cross-covariance fraction =  0.50%
# Component 23: singular value = 1.370607 | cross-covariance fraction =  0.48%
# Component 24: singular value = 1.305302 | cross-covariance fraction =  0.44%
# Component 25: singular value = 1.238429 | cross-covariance fraction =  0.39%
# Component 26: singular value = 1.176606 | cross-covariance fraction =  0.35%
# Component 27: singular value = 1.171358 | cross-covariance fraction =  0.35%
# Component 28: singular value = 1.098854 | cross-covariance fraction =  0.31%
# Component 29: singular value = 1.029754 | cross-covariance fraction =  0.27%
# Component 30: singular value = 1.015582 | cross-covariance fraction =  0.26%
# Component 31: singular value = 0.959410 | cross-covariance fraction =  0.24%
# Component 32: singular value = 0.944814 | cross-covariance fraction =  0.23%
# Component 33: singular value = 0.882440 | cross-covariance fraction =  0.20%
# Component 34: singular value = 0.803593 | cross-covariance fraction =  0.17%
# Component 35: singular value = 0.745467 | cross-covariance fraction =  0.14%
# Component 36: singular value = 0.725513 | cross-covariance fraction =  0.13%
# Component 37: singular value = 0.676866 | cross-covariance fraction =  0.12%
# Component 38: singular value = 0.651128 | cross-covariance fraction =  0.11%
# Component 39: singular value = 0.594186 | cross-covariance fraction =  0.09%
# Component 40: singular value = 0.498784 | cross-covariance fraction =  0.06%
# Component 41: singular value = 0.449470 | cross-covariance fraction =  0.05%
# Component 42: singular value = 0.406573 | cross-covariance fraction =  0.04%
# Component 43: singular value = 0.376078 | cross-covariance fraction =  0.04%
# Component 44: singular value = 0.300426 | cross-covariance fraction =  0.02%
#
# 🔹 Variance explained in ORIGINAL neural PC data by cross-covariance components...
# ===== Neural PCA variance explained by cross-covariance components =====
# Cross-cov comp  1: explained var in neural PCA space =  4.20% | cumulative =  4.20%
# Cross-cov comp  2: explained var in neural PCA space =  3.31% | cumulative =  7.50%
# Cross-cov comp  3: explained var in neural PCA space =  3.09% | cumulative = 10.59%
# Cross-cov comp  4: explained var in neural PCA space =  2.12% | cumulative = 12.71%
# Cross-cov comp  5: explained var in neural PCA space =  2.81% | cumulative = 15.52%
# Cross-cov comp  6: explained var in neural PCA space =  2.95% | cumulative = 18.47%
# Cross-cov comp  7: explained var in neural PCA space =  1.74% | cumulative = 20.22%
# Cross-cov comp  8: explained var in neural PCA space =  1.82% | cumulative = 22.04%
# Cross-cov comp  9: explained var in neural PCA space =  1.76% | cumulative = 23.80%
# Cross-cov comp 10: explained var in neural PCA space =  1.52% | cumulative = 25.32%
# Cross-cov comp 11: explained var in neural PCA space =  1.63% | cumulative = 26.95%
# Cross-cov comp 12: explained var in neural PCA space =  1.66% | cumulative = 28.60%
# Cross-cov comp 13: explained var in neural PCA space =  1.57% | cumulative = 30.17%
# Cross-cov comp 14: explained var in neural PCA space =  1.89% | cumulative = 32.06%
# Cross-cov comp 15: explained var in neural PCA space =  1.58% | cumulative = 33.64%
# Cross-cov comp 16: explained var in neural PCA space =  1.53% | cumulative = 35.17%
# Cross-cov comp 17: explained var in neural PCA space =  1.46% | cumulative = 36.63%
# Cross-cov comp 18: explained var in neural PCA space =  1.25% | cumulative = 37.87%
# Cross-cov comp 19: explained var in neural PCA space =  1.53% | cumulative = 39.40%
# Cross-cov comp 20: explained var in neural PCA space =  1.35% | cumulative = 40.75%
# Cross-cov comp 21: explained var in neural PCA space =  1.23% | cumulative = 41.98%
# Cross-cov comp 22: explained var in neural PCA space =  1.26% | cumulative = 43.23%
# Cross-cov comp 23: explained var in neural PCA space =  1.59% | cumulative = 44.83%
# Cross-cov comp 24: explained var in neural PCA space =  1.47% | cumulative = 46.29%
# Cross-cov comp 25: explained var in neural PCA space =  1.11% | cumulative = 47.40%
# Cross-cov comp 26: explained var in neural PCA space =  1.28% | cumulative = 48.67%
# Cross-cov comp 27: explained var in neural PCA space =  1.09% | cumulative = 49.76%
# Cross-cov comp 28: explained var in neural PCA space =  1.16% | cumulative = 50.92%
# Cross-cov comp 29: explained var in neural PCA space =  1.24% | cumulative = 52.16%
# Cross-cov comp 30: explained var in neural PCA space =  1.43% | cumulative = 53.59%
# Cross-cov comp 31: explained var in neural PCA space =  1.15% | cumulative = 54.74%
# Cross-cov comp 32: explained var in neural PCA space =  1.10% | cumulative = 55.84%
# Cross-cov comp 33: explained var in neural PCA space =  1.02% | cumulative = 56.86%
# Cross-cov comp 34: explained var in neural PCA space =  1.13% | cumulative = 57.99%
# Cross-cov comp 35: explained var in neural PCA space =  1.16% | cumulative = 59.16%
# Cross-cov comp 36: explained var in neural PCA space =  1.06% | cumulative = 60.22%
# Cross-cov comp 37: explained var in neural PCA space =  0.98% | cumulative = 61.19%
# Cross-cov comp 38: explained var in neural PCA space =  1.12% | cumulative = 62.31%
# Cross-cov comp 39: explained var in neural PCA space =  1.27% | cumulative = 63.58%
# Cross-cov comp 40: explained var in neural PCA space =  1.20% | cumulative = 64.78%
# Cross-cov comp 41: explained var in neural PCA space =  1.06% | cumulative = 65.84%
# Cross-cov comp 42: explained var in neural PCA space =  1.00% | cumulative = 66.85%
# Cross-cov comp 43: explained var in neural PCA space =  1.10% | cumulative = 67.94%
# Cross-cov comp 44: explained var in neural PCA space =  1.01% | cumulative = 68.95%
#
# ✅ Total variance in ORIGINAL neural PC data accounted for (sum over all cross-cov comps): 68.95%
# 💾 Saved results to vit_VISl_pca_cvpca_crosscov_results.npz

# %%
#!/usr/bin/env python3
"""
Two-stage cvPCA pipeline with an initial PCA bottleneck:

1) ViT:
   - Softmax + CLR on logits for natural scenes
   - PCA → keep PCs up to VAR_CUTOFF variance

2) Neural:
   (a) Preprocess:
       - Load deconvolved responses
       - Select AREA_NAME
       - Reshape to (neurons × images × trials × time)
       - Compute stimulus-locked means
   (b) PCA on stimulus-locked means (all trials):
       - Xa = R_all.T  (images × neurons)
       - PCA → keep PCs up to VAR_CUTOFF variance
       - Get neural PC scores: Xa_pca (images × n_neural_pca)
   (c) cvPCA in neural PC space:
       - Split trials into even/odd → R_even, R_odd
       - Project to PCA space → Xe_pca, Xo_pca
       - cvPCA (Pachitariu-style) on these PC scores
       - Get neural cvPCA basis inside PCA space + shared variances
       - Get stimulus-locked neural cvPCA scores Zb_cv (images × n_cvpca)

3) Cross-covariance SVD:
   - Between ViT PC scores Zv and neural cvPCA scores Zb_cv
   - SVD of cross-covariance → shared directions U_cv, V_cv

4) Variance explained in original neural PC data:
   - Map cross-covariance components back into the original neural PCA space
   - Compute fraction of variance in Xa_pca explained by those components
"""

import numpy as np
import pickle
from sklearn.decomposition import PCA
from scipy.special import softmax
from skbio.stats.composition import clr

# ---------------------------------------------------------------
# CONFIG
# ---------------------------------------------------------------
VIT_PATH    = '/home/maria/Documents/HuggingMouseData/MouseViTEmbeddings/google_vit-base-patch16-224_embeddings_logits.pkl'
NEURAL_PATH = '/home/maria/LuckyMouse/pixel_transformer_neuro/data/processed/hybrid_neural_responses.npy'
AREAS_PATH  = '/home/maria/MITNeuralComputation/visualization/brain_area.npy'

AREA_NAME   = 'VISp'
AREA_NAME='VISrl'
AREA_NAME='VISal'
AREA_NAME='VISl'
AREA_NAME='VISpm'
N_IMAGES    = 118
N_TRIALS    = 50
VAR_CUTOFF  = 0.90
RANDOM_SEED = 42

rng = np.random.default_rng(RANDOM_SEED)

# ===============================================================
# STEP 1: ViT preprocessing (softmax + CLR + PCA)
# ===============================================================
print("🔹 Loading ViT embeddings...")
with open(VIT_PATH, 'rb') as f:
    vit_logits = pickle.load(f)['natural_scenes']  # (N_IMAGES × D_vit)

Xv = np.asarray(vit_logits)
Xv = softmax(Xv, axis=1)          # probabilities over classes
Xv = clr(Xv + 1e-12)              # CLR transform

print("🔹 PCA on ViT CLR embeddings...")
vit_pca_full = PCA(random_state=RANDOM_SEED).fit(Xv)
vit_cumvar = np.cumsum(vit_pca_full.explained_variance_ratio_)
vit_ncomp = np.searchsorted(vit_cumvar, VAR_CUTOFF) + 1

vit_pca = PCA(n_components=vit_ncomp, random_state=RANDOM_SEED)
Zv = vit_pca.fit_transform(Xv)    # (images × vit_ncomp)

print(f"✅ ViT PCs covering {VAR_CUTOFF*100:.0f}% variance: {vit_ncomp}")

# ===============================================================
# STEP 2: Neural preprocessing + FIRST PCA (to 90% var)
# ===============================================================
print(f"\n🔹 Loading neural responses, area = {AREA_NAME}...")
dat_all = np.load(NEURAL_PATH, mmap_mode='r')   # (n_neurons_total × (images*trials*time))
areas = np.load(AREAS_PATH, allow_pickle=True)  # (n_neurons_total,)

area_mask = (areas == AREA_NAME)
dat = dat_all[area_mask]                        # (n_neurons_area × n_total)
n_neurons, n_total = dat.shape

# Infer time bins
n_time = n_total // (N_IMAGES * N_TRIALS)
if N_IMAGES * N_TRIALS * n_time != n_total:
    raise ValueError(f"Inferred n_time={n_time} inconsistent with data shape.")

print(f"   → {n_neurons} neurons, n_total={n_total}, inferred n_time={n_time}")

# Reshape to (neurons × images × trials × time)
dat = dat.reshape(n_neurons, N_IMAGES, N_TRIALS, n_time)

# Stimulus-locked means:
# - R_even, R_odd: for cvPCA
# - R_all: all trials, for the initial PCA
even_idx = np.arange(0, N_TRIALS, 2)
odd_idx  = np.arange(1, N_TRIALS, 2)
print(f"   → Even trials: {even_idx.size}, odd trials: {odd_idx.size}")

R_even = dat[:, :, even_idx, :].mean(axis=(2, 3))   # (neurons × images)
R_odd  = dat[:, :, odd_idx,  :].mean(axis=(2, 3))   # (neurons × images)
R_all  = dat.mean(axis=(2, 3))                      # (neurons × images)

# For PCA: samples = images, features = neurons
Xa = R_all.T    # (images × neurons)
Xe = R_even.T   # (images × neurons)
Xo = R_odd.T    # (images × neurons)

print("\n🔹 FIRST PCA on stimulus-locked neural responses (all trials)...")
neural_pca_full = PCA(random_state=RANDOM_SEED).fit(Xa)
neural_cumvar = np.cumsum(neural_pca_full.explained_variance_ratio_)
neural_ncomp = np.searchsorted(neural_cumvar, VAR_CUTOFF) + 1

neural_pca = PCA(n_components=neural_ncomp, random_state=RANDOM_SEED)
Xa_pca = neural_pca.fit_transform(Xa)   # (images × neural_ncomp)
Xe_pca = neural_pca.transform(Xe)       # (images × neural_ncomp)
Xo_pca = neural_pca.transform(Xo)       # (images × neural_ncomp)

print(f"✅ Neural PCs (first stage) covering {VAR_CUTOFF*100:.0f}% variance: {neural_ncomp}")

# PCA basis in neuron space (neurons × neural_ncomp)
# sklearn: components_ is (n_components × n_features)
W_pca_neurons = neural_pca.components_.T

# ===============================================================
# STEP 3: cvPCA in neural PCA space
# ===============================================================
print("\n🔹 Running cvPCA on neural PCA scores (stimulus-locked)...")

n_stim = N_IMAGES

# Xe_pca and Xo_pca are already centered using the same mean in neuron space;
# we can treat them as zero-mean PC scores.
Xe0 = Xe_pca
Xo0 = Xo_pca

# Covariance of train (even) half in PCA space
Cb_pca = Xe0.T @ Xe0 / (n_stim - 1)      # (neural_ncomp × neural_ncomp)

# Eigen-decomposition in PCA space
eigvals, V_pca = np.linalg.eigh(Cb_pca)
idx = np.argsort(eigvals)[::-1]
eigvals = eigvals[idx]
V_pca = V_pca[:, idx]                    # (neural_ncomp × neural_ncomp)

# Project both halves onto these components (still in PCA space)
S1 = Xe0 @ V_pca                         # (images × neural_ncomp)
S2 = Xo0 @ V_pca                         # (images × neural_ncomp)

# Cross-validated variance per component
lam_cv = np.sum(S1 * S2, axis=0) / (n_stim - 1)   # (neural_ncomp,)

# Clamp negatives (noise)
lam_cv_pos = np.maximum(lam_cv, 0.0)
total_shared = lam_cv_pos.sum()
if total_shared <= 0:
    raise RuntimeError("Total shared variance (cvPCA) non-positive. Check data/splits.")

shared_frac = lam_cv_pos / total_shared
cum_shared_frac = np.cumsum(shared_frac)

# Pick number of cvPCA components by shared variance cutoff
brain_ncomp = np.searchsorted(cum_shared_frac, VAR_CUTOFF) + 1
brain_ncomp = min(brain_ncomp, V_pca.shape[1])

print("===== Neural cvPCA (in PCA space) =====")
for i in range(brain_ncomp):
    print(f"cvPC {i+1:2d}: shared var = {lam_cv_pos[i]:.6f} | "
          f"fraction = {shared_frac[i]*100:5.2f}% | "
          f"cumulative = {cum_shared_frac[i]*100:5.2f}%")

print(f"\n✅ Using first {brain_ncomp} cvPCA components as neural stimulus-locked basis "
      f"in PCA space (covering {cum_shared_frac[brain_ncomp-1]*100:.2f}% shared variance).")

# Neural cvPCA basis inside PCA space (neural_ncomp × brain_ncomp)
W_cvpca_pca = V_pca[:, :brain_ncomp]

# Now get neural cvPCA scores for ALL trials (Xa_pca) in this basis:
Zb_cv = Xa_pca @ W_cvpca_pca           # (images × brain_ncomp)

# Optionally, you can also get cvPCA basis back in neuron space:
# W_neural_cv = W_pca_neurons @ W_cvpca_pca   # (neurons × brain_ncomp)


# ===============================================================
# STEP 4: Cross-covariance between ViT PCs and neural cvPCA scores
# ===============================================================
print("\n🔹 Cross-covariance SVD between ViT PCs and neural cvPCA scores...")

# Center across images
Zv0 = Zv - Zv.mean(axis=0, keepdims=True)      # (images × vit_ncomp)
Zb0 = Zb_cv - Zb_cv.mean(axis=0, keepdims=True)  # (images × brain_ncomp)

# Cross-covariance
C_vb = (Zv0.T @ Zb0) / (n_stim - 1)            # (vit_ncomp × brain_ncomp)

# SVD of cross-covariance
U_cv, S_cv, Vt_cv = np.linalg.svd(C_vb, full_matrices=False)
V_cv = Vt_cv.T                                  # (brain_ncomp × r)

shared_cov_frac = (S_cv**2) / np.sum(S_cv**2)

print("===== Cross-covariance components (ViT ↔ neural cvPCA) =====")
for i, (s, frac) in enumerate(zip(S_cv, shared_cov_frac), start=1):
    print(f"Component {i:2d}: singular value = {s:.6f} | "
          f"cross-covariance fraction = {frac*100:5.2f}%")


# ===============================================================
# STEP 5: Variance explained in ORIGINAL neural PC data
#         by cross-covariance components
# ===============================================================
print("\n🔹 Variance explained in ORIGINAL neural PC data by cross-covariance components...")

# Original neural PC scores from FIRST PCA:
# Xa_pca: (images × neural_ncomp)
Xa_pca0 = Xa_pca - Xa_pca.mean(axis=0, keepdims=True)

# Total variance in original neural PCA space
total_var_neural_pca = np.sum(np.var(Xa_pca0, axis=0, ddof=1))

# Map cross-cov components from cvPCA space back into original neural PCA space:
# W_cvpca_pca: (neural_ncomp × brain_ncomp)
# V_cv:        (brain_ncomp × r)
# → B_pca:     (neural_ncomp × r), directions in original neural PCA space
B_pca = W_cvpca_pca @ V_cv                   # (neural_ncomp × r)

# Project original neural PC scores onto these cross-cov directions
Xb_cc_pca = Xa_pca0 @ B_pca                  # (images × r)

# Variance per cross-cov component in original neural PCA space
var_cc = np.var(Xb_cc_pca, axis=0, ddof=1)   # (r,)
frac_cc = var_cc / total_var_neural_pca
cum_frac_cc = np.cumsum(frac_cc)

print("===== Neural PCA variance explained by cross-covariance components =====")
for i, (f, cf) in enumerate(zip(frac_cc, cum_frac_cc), start=1):
    print(f"Cross-cov comp {i:2d}: "
          f"explained var in neural PCA space = {f*100:5.2f}% | "
          f"cumulative = {cf*100:5.2f}%")

print(f"\n✅ Total variance in ORIGINAL neural PC data accounted for "
      f"(sum over all cross-cov comps): {frac_cc.sum()*100:.2f}%")

# ===============================================================
# STEP 6: Save everything
# ===============================================================
out_name = f"vit_{AREA_NAME}_pca_cvpca_crosscov_results.npz"
np.savez(
    out_name,
    # ViT
    vit_scores=Zv,
    vit_basis=vit_pca.components_,
    vit_explained_var=vit_pca.explained_variance_ratio_,
    # Neural PCA
    neural_pca_scores=Xa_pca,
    neural_pca_basis=W_pca_neurons,
    neural_pca_explained_var=neural_pca.explained_variance_ratio_,
    # Neural cvPCA
    neural_cvpca_basis_pca=W_cvpca_pca,
    neural_cvpca_shared_var=lam_cv_pos[:brain_ncomp],
    neural_cvpca_shared_frac=shared_frac[:brain_ncomp],
    neural_cvpca_scores=Zb_cv,
    # Cross-covariance
    crosscov_matrix=C_vb,
    crosscov_singular_values=S_cv,
    crosscov_vit_basis=U_cv,
    crosscov_neural_cvpca_basis=V_cv,
    # Variance explained in ORIGINAL neural PCA space
    neural_pca_var_per_cc=var_cc,
    neural_pca_var_fraction_per_cc=frac_cc,
)

print(f"💾 Saved results to {out_name}")
# Out:
# 🔹 Loading ViT embeddings...
# 🔹 PCA on ViT CLR embeddings...
# ✅ ViT PCs covering 90% variance: 44
#
# 🔹 Loading neural responses, area = VISpm...
#    → 4771 neurons, n_total=5900, inferred n_time=1
#    → Even trials: 25, odd trials: 25
#
# 🔹 FIRST PCA on stimulus-locked neural responses (all trials)...
# ✅ Neural PCs (first stage) covering 90% variance: 83
#
# 🔹 Running cvPCA on neural PCA scores (stimulus-locked)...
# ===== Neural cvPCA (in PCA space) =====
# cvPC  1: shared var = 1.064984 | fraction = 10.20% | cumulative = 10.20%
# cvPC  2: shared var = 0.662176 | fraction =  6.34% | cumulative = 16.55%
# cvPC  3: shared var = 0.556182 | fraction =  5.33% | cumulative = 21.87%
# cvPC  4: shared var = 0.429244 | fraction =  4.11% | cumulative = 25.99%
# cvPC  5: shared var = 0.355752 | fraction =  3.41% | cumulative = 29.39%
# cvPC  6: shared var = 0.322558 | fraction =  3.09% | cumulative = 32.48%
# cvPC  7: shared var = 0.308920 | fraction =  2.96% | cumulative = 35.44%
# cvPC  8: shared var = 0.251832 | fraction =  2.41% | cumulative = 37.86%
# cvPC  9: shared var = 0.233771 | fraction =  2.24% | cumulative = 40.10%
# cvPC 10: shared var = 0.210652 | fraction =  2.02% | cumulative = 42.11%
# cvPC 11: shared var = 0.195525 | fraction =  1.87% | cumulative = 43.99%
# cvPC 12: shared var = 0.187145 | fraction =  1.79% | cumulative = 45.78%
# cvPC 13: shared var = 0.177951 | fraction =  1.70% | cumulative = 47.48%
# cvPC 14: shared var = 0.166361 | fraction =  1.59% | cumulative = 49.08%
# cvPC 15: shared var = 0.149804 | fraction =  1.44% | cumulative = 50.51%
# cvPC 16: shared var = 0.148077 | fraction =  1.42% | cumulative = 51.93%
# cvPC 17: shared var = 0.144352 | fraction =  1.38% | cumulative = 53.31%
# cvPC 18: shared var = 0.139542 | fraction =  1.34% | cumulative = 54.65%
# cvPC 19: shared var = 0.128138 | fraction =  1.23% | cumulative = 55.88%
# cvPC 20: shared var = 0.133279 | fraction =  1.28% | cumulative = 57.16%
# cvPC 21: shared var = 0.120161 | fraction =  1.15% | cumulative = 58.31%
# cvPC 22: shared var = 0.120180 | fraction =  1.15% | cumulative = 59.46%
# cvPC 23: shared var = 0.118066 | fraction =  1.13% | cumulative = 60.59%
# cvPC 24: shared var = 0.112062 | fraction =  1.07% | cumulative = 61.66%
# cvPC 25: shared var = 0.103346 | fraction =  0.99% | cumulative = 62.65%
# cvPC 26: shared var = 0.100813 | fraction =  0.97% | cumulative = 63.62%
# cvPC 27: shared var = 0.106395 | fraction =  1.02% | cumulative = 64.64%
# cvPC 28: shared var = 0.097454 | fraction =  0.93% | cumulative = 65.57%
# cvPC 29: shared var = 0.102451 | fraction =  0.98% | cumulative = 66.55%
# cvPC 30: shared var = 0.091528 | fraction =  0.88% | cumulative = 67.43%
# cvPC 31: shared var = 0.094196 | fraction =  0.90% | cumulative = 68.33%
# cvPC 32: shared var = 0.090857 | fraction =  0.87% | cumulative = 69.20%
# cvPC 33: shared var = 0.094410 | fraction =  0.90% | cumulative = 70.11%
# cvPC 34: shared var = 0.091664 | fraction =  0.88% | cumulative = 70.98%
# cvPC 35: shared var = 0.086925 | fraction =  0.83% | cumulative = 71.82%
# cvPC 36: shared var = 0.086292 | fraction =  0.83% | cumulative = 72.64%
# cvPC 37: shared var = 0.081891 | fraction =  0.78% | cumulative = 73.43%
# cvPC 38: shared var = 0.080357 | fraction =  0.77% | cumulative = 74.20%
# cvPC 39: shared var = 0.081293 | fraction =  0.78% | cumulative = 74.98%
# cvPC 40: shared var = 0.079492 | fraction =  0.76% | cumulative = 75.74%
# cvPC 41: shared var = 0.075545 | fraction =  0.72% | cumulative = 76.46%
# cvPC 42: shared var = 0.079931 | fraction =  0.77% | cumulative = 77.23%
# cvPC 43: shared var = 0.072311 | fraction =  0.69% | cumulative = 77.92%
# cvPC 44: shared var = 0.071564 | fraction =  0.69% | cumulative = 78.61%
# cvPC 45: shared var = 0.075822 | fraction =  0.73% | cumulative = 79.33%
# cvPC 46: shared var = 0.072162 | fraction =  0.69% | cumulative = 80.02%
# cvPC 47: shared var = 0.071078 | fraction =  0.68% | cumulative = 80.70%
# cvPC 48: shared var = 0.068180 | fraction =  0.65% | cumulative = 81.36%
# cvPC 49: shared var = 0.067500 | fraction =  0.65% | cumulative = 82.00%
# cvPC 50: shared var = 0.066160 | fraction =  0.63% | cumulative = 82.64%
# cvPC 51: shared var = 0.064218 | fraction =  0.62% | cumulative = 83.25%
# cvPC 52: shared var = 0.063409 | fraction =  0.61% | cumulative = 83.86%
# cvPC 53: shared var = 0.065766 | fraction =  0.63% | cumulative = 84.49%
# cvPC 54: shared var = 0.064687 | fraction =  0.62% | cumulative = 85.11%
# cvPC 55: shared var = 0.063848 | fraction =  0.61% | cumulative = 85.72%
# cvPC 56: shared var = 0.061745 | fraction =  0.59% | cumulative = 86.31%
# cvPC 57: shared var = 0.060911 | fraction =  0.58% | cumulative = 86.90%
# cvPC 58: shared var = 0.060110 | fraction =  0.58% | cumulative = 87.47%
# cvPC 59: shared var = 0.060303 | fraction =  0.58% | cumulative = 88.05%
# cvPC 60: shared var = 0.060798 | fraction =  0.58% | cumulative = 88.63%
# cvPC 61: shared var = 0.058722 | fraction =  0.56% | cumulative = 89.20%
# cvPC 62: shared var = 0.057402 | fraction =  0.55% | cumulative = 89.75%
# cvPC 63: shared var = 0.056001 | fraction =  0.54% | cumulative = 90.28%
#
# ✅ Using first 63 cvPCA components as neural stimulus-locked basis in PCA space (covering 90.28% shared variance).
#
# 🔹 Cross-covariance SVD between ViT PCs and neural cvPCA scores...
# ===== Cross-covariance components (ViT ↔ neural cvPCA) =====
# Component  1: singular value = 7.809117 | cross-covariance fraction = 39.43%
# Component  2: singular value = 5.604590 | cross-covariance fraction = 20.31%
# Component  3: singular value = 3.708897 | cross-covariance fraction =  8.89%
# Component  4: singular value = 2.588270 | cross-covariance fraction =  4.33%
# Component  5: singular value = 2.303167 | cross-covariance fraction =  3.43%
# Component  6: singular value = 2.123940 | cross-covariance fraction =  2.92%
# Component  7: singular value = 1.979876 | cross-covariance fraction =  2.53%
# Component  8: singular value = 1.664099 | cross-covariance fraction =  1.79%
# Component  9: singular value = 1.593983 | cross-covariance fraction =  1.64%
# Component 10: singular value = 1.550476 | cross-covariance fraction =  1.55%
# Component 11: singular value = 1.401039 | cross-covariance fraction =  1.27%
# Component 12: singular value = 1.368616 | cross-covariance fraction =  1.21%
# Component 13: singular value = 1.283861 | cross-covariance fraction =  1.07%
# Component 14: singular value = 1.210397 | cross-covariance fraction =  0.95%
# Component 15: singular value = 1.145087 | cross-covariance fraction =  0.85%
# Component 16: singular value = 1.053189 | cross-covariance fraction =  0.72%
# Component 17: singular value = 1.019241 | cross-covariance fraction =  0.67%
# Component 18: singular value = 0.976497 | cross-covariance fraction =  0.62%
# Component 19: singular value = 0.940656 | cross-covariance fraction =  0.57%
# Component 20: singular value = 0.872829 | cross-covariance fraction =  0.49%
# Component 21: singular value = 0.854525 | cross-covariance fraction =  0.47%
# Component 22: singular value = 0.801197 | cross-covariance fraction =  0.42%
# Component 23: singular value = 0.756025 | cross-covariance fraction =  0.37%
# Component 24: singular value = 0.738693 | cross-covariance fraction =  0.35%
# Component 25: singular value = 0.725888 | cross-covariance fraction =  0.34%
# Component 26: singular value = 0.703543 | cross-covariance fraction =  0.32%
# Component 27: singular value = 0.688616 | cross-covariance fraction =  0.31%
# Component 28: singular value = 0.667264 | cross-covariance fraction =  0.29%
# Component 29: singular value = 0.640485 | cross-covariance fraction =  0.27%
# Component 30: singular value = 0.590958 | cross-covariance fraction =  0.23%
# Component 31: singular value = 0.544157 | cross-covariance fraction =  0.19%
# Component 32: singular value = 0.523236 | cross-covariance fraction =  0.18%
# Component 33: singular value = 0.488932 | cross-covariance fraction =  0.15%
# Component 34: singular value = 0.471055 | cross-covariance fraction =  0.14%
# Component 35: singular value = 0.451593 | cross-covariance fraction =  0.13%
# Component 36: singular value = 0.444917 | cross-covariance fraction =  0.13%
# Component 37: singular value = 0.409649 | cross-covariance fraction =  0.11%
# Component 38: singular value = 0.363972 | cross-covariance fraction =  0.09%
# Component 39: singular value = 0.344190 | cross-covariance fraction =  0.08%
# Component 40: singular value = 0.314012 | cross-covariance fraction =  0.06%
# Component 41: singular value = 0.276790 | cross-covariance fraction =  0.05%
# Component 42: singular value = 0.240938 | cross-covariance fraction =  0.04%
# Component 43: singular value = 0.215627 | cross-covariance fraction =  0.03%
# Component 44: singular value = 0.145247 | cross-covariance fraction =  0.01%
#
# 🔹 Variance explained in ORIGINAL neural PC data by cross-covariance components...
# ===== Neural PCA variance explained by cross-covariance components =====
# Cross-cov comp  1: explained var in neural PCA space =  5.21% | cumulative =  5.21%
# Cross-cov comp  2: explained var in neural PCA space =  4.41% | cumulative =  9.62%
# Cross-cov comp  3: explained var in neural PCA space =  6.79% | cumulative = 16.41%
# Cross-cov comp  4: explained var in neural PCA space =  2.04% | cumulative = 18.45%
# Cross-cov comp  5: explained var in neural PCA space =  3.04% | cumulative = 21.49%
# Cross-cov comp  6: explained var in neural PCA space =  2.76% | cumulative = 24.26%
# Cross-cov comp  7: explained var in neural PCA space =  2.73% | cumulative = 26.99%
# Cross-cov comp  8: explained var in neural PCA space =  1.78% | cumulative = 28.76%
# Cross-cov comp  9: explained var in neural PCA space =  1.60% | cumulative = 30.36%
# Cross-cov comp 10: explained var in neural PCA space =  1.42% | cumulative = 31.78%
# Cross-cov comp 11: explained var in neural PCA space =  1.99% | cumulative = 33.77%
# Cross-cov comp 12: explained var in neural PCA space =  1.22% | cumulative = 34.99%
# Cross-cov comp 13: explained var in neural PCA space =  1.73% | cumulative = 36.72%
# Cross-cov comp 14: explained var in neural PCA space =  1.73% | cumulative = 38.45%
# Cross-cov comp 15: explained var in neural PCA space =  1.46% | cumulative = 39.91%
# Cross-cov comp 16: explained var in neural PCA space =  2.41% | cumulative = 42.32%
# Cross-cov comp 17: explained var in neural PCA space =  1.17% | cumulative = 43.49%
# Cross-cov comp 18: explained var in neural PCA space =  1.27% | cumulative = 44.76%
# Cross-cov comp 19: explained var in neural PCA space =  1.27% | cumulative = 46.02%
# Cross-cov comp 20: explained var in neural PCA space =  1.19% | cumulative = 47.21%
# Cross-cov comp 21: explained var in neural PCA space =  1.25% | cumulative = 48.46%
# Cross-cov comp 22: explained var in neural PCA space =  1.06% | cumulative = 49.52%
# Cross-cov comp 23: explained var in neural PCA space =  1.16% | cumulative = 50.68%
# Cross-cov comp 24: explained var in neural PCA space =  1.07% | cumulative = 51.75%
# Cross-cov comp 25: explained var in neural PCA space =  1.26% | cumulative = 53.01%
# Cross-cov comp 26: explained var in neural PCA space =  1.08% | cumulative = 54.09%
# Cross-cov comp 27: explained var in neural PCA space =  0.90% | cumulative = 54.99%
# Cross-cov comp 28: explained var in neural PCA space =  1.26% | cumulative = 56.26%
# Cross-cov comp 29: explained var in neural PCA space =  1.16% | cumulative = 57.42%
# Cross-cov comp 30: explained var in neural PCA space =  1.09% | cumulative = 58.51%
# Cross-cov comp 31: explained var in neural PCA space =  1.06% | cumulative = 59.57%
# Cross-cov comp 32: explained var in neural PCA space =  0.89% | cumulative = 60.46%
# Cross-cov comp 33: explained var in neural PCA space =  1.04% | cumulative = 61.50%
# Cross-cov comp 34: explained var in neural PCA space =  1.09% | cumulative = 62.59%
# Cross-cov comp 35: explained var in neural PCA space =  1.06% | cumulative = 63.65%
# Cross-cov comp 36: explained var in neural PCA space =  1.09% | cumulative = 64.75%
# Cross-cov comp 37: explained var in neural PCA space =  0.95% | cumulative = 65.70%
# Cross-cov comp 38: explained var in neural PCA space =  1.03% | cumulative = 66.73%
# Cross-cov comp 39: explained var in neural PCA space =  0.94% | cumulative = 67.67%
# Cross-cov comp 40: explained var in neural PCA space =  0.89% | cumulative = 68.56%
# Cross-cov comp 41: explained var in neural PCA space =  0.93% | cumulative = 69.48%
# Cross-cov comp 42: explained var in neural PCA space =  1.00% | cumulative = 70.48%
# Cross-cov comp 43: explained var in neural PCA space =  0.82% | cumulative = 71.30%
# Cross-cov comp 44: explained var in neural PCA space =  1.04% | cumulative = 72.35%
#
# ✅ Total variance in ORIGINAL neural PC data accounted for (sum over all cross-cov comps): 72.35%
# 💾 Saved results to vit_VISpm_pca_cvpca_crosscov_results.npz

# %%
#!/usr/bin/env python3
"""
Two-stage cvPCA pipeline with an initial PCA bottleneck:

1) ViT:
   - Softmax + CLR on logits for natural scenes
   - PCA → keep PCs up to VAR_CUTOFF variance

2) Neural:
   (a) Preprocess:
       - Load deconvolved responses
       - Select AREA_NAME
       - Reshape to (neurons × images × trials × time)
       - Compute stimulus-locked means
   (b) PCA on stimulus-locked means (all trials):
       - Xa = R_all.T  (images × neurons)
       - PCA → keep PCs up to VAR_CUTOFF variance
       - Get neural PC scores: Xa_pca (images × n_neural_pca)
   (c) cvPCA in neural PC space:
       - Split trials into even/odd → R_even, R_odd
       - Project to PCA space → Xe_pca, Xo_pca
       - cvPCA (Pachitariu-style) on these PC scores
       - Get neural cvPCA basis inside PCA space + shared variances
       - Get stimulus-locked neural cvPCA scores Zb_cv (images × n_cvpca)

3) Cross-covariance SVD:
   - Between ViT PC scores Zv and neural cvPCA scores Zb_cv
   - SVD of cross-covariance → shared directions U_cv, V_cv

4) Variance explained in original neural PC data:
   - Map cross-covariance components back into the original neural PCA space
   - Compute fraction of variance in Xa_pca explained by those components
"""

import numpy as np
import pickle
from sklearn.decomposition import PCA
from scipy.special import softmax
from skbio.stats.composition import clr

# ---------------------------------------------------------------
# CONFIG
# ---------------------------------------------------------------
VIT_PATH    = '/home/maria/Documents/HuggingMouseData/MouseViTEmbeddings/google_vit-base-patch16-224_embeddings_logits.pkl'
NEURAL_PATH = '/home/maria/LuckyMouse/pixel_transformer_neuro/data/processed/hybrid_neural_responses.npy'
AREAS_PATH  = '/home/maria/MITNeuralComputation/visualization/brain_area.npy'

AREA_NAME   = 'VISp'
AREA_NAME='VISrl'
AREA_NAME='VISal'
AREA_NAME='VISl'
AREA_NAME='VISpm'
AREA_NAME='VISam'
N_IMAGES    = 118
N_TRIALS    = 50
VAR_CUTOFF  = 0.90
RANDOM_SEED = 42

rng = np.random.default_rng(RANDOM_SEED)

# ===============================================================
# STEP 1: ViT preprocessing (softmax + CLR + PCA)
# ===============================================================
print("🔹 Loading ViT embeddings...")
with open(VIT_PATH, 'rb') as f:
    vit_logits = pickle.load(f)['natural_scenes']  # (N_IMAGES × D_vit)

Xv = np.asarray(vit_logits)
Xv = softmax(Xv, axis=1)          # probabilities over classes
Xv = clr(Xv + 1e-12)              # CLR transform

print("🔹 PCA on ViT CLR embeddings...")
vit_pca_full = PCA(random_state=RANDOM_SEED).fit(Xv)
vit_cumvar = np.cumsum(vit_pca_full.explained_variance_ratio_)
vit_ncomp = np.searchsorted(vit_cumvar, VAR_CUTOFF) + 1

vit_pca = PCA(n_components=vit_ncomp, random_state=RANDOM_SEED)
Zv = vit_pca.fit_transform(Xv)    # (images × vit_ncomp)

print(f"✅ ViT PCs covering {VAR_CUTOFF*100:.0f}% variance: {vit_ncomp}")

# ===============================================================
# STEP 2: Neural preprocessing + FIRST PCA (to 90% var)
# ===============================================================
print(f"\n🔹 Loading neural responses, area = {AREA_NAME}...")
dat_all = np.load(NEURAL_PATH, mmap_mode='r')   # (n_neurons_total × (images*trials*time))
areas = np.load(AREAS_PATH, allow_pickle=True)  # (n_neurons_total,)

area_mask = (areas == AREA_NAME)
dat = dat_all[area_mask]                        # (n_neurons_area × n_total)
n_neurons, n_total = dat.shape

# Infer time bins
n_time = n_total // (N_IMAGES * N_TRIALS)
if N_IMAGES * N_TRIALS * n_time != n_total:
    raise ValueError(f"Inferred n_time={n_time} inconsistent with data shape.")

print(f"   → {n_neurons} neurons, n_total={n_total}, inferred n_time={n_time}")

# Reshape to (neurons × images × trials × time)
dat = dat.reshape(n_neurons, N_IMAGES, N_TRIALS, n_time)

# Stimulus-locked means:
# - R_even, R_odd: for cvPCA
# - R_all: all trials, for the initial PCA
even_idx = np.arange(0, N_TRIALS, 2)
odd_idx  = np.arange(1, N_TRIALS, 2)
print(f"   → Even trials: {even_idx.size}, odd trials: {odd_idx.size}")

R_even = dat[:, :, even_idx, :].mean(axis=(2, 3))   # (neurons × images)
R_odd  = dat[:, :, odd_idx,  :].mean(axis=(2, 3))   # (neurons × images)
R_all  = dat.mean(axis=(2, 3))                      # (neurons × images)

# For PCA: samples = images, features = neurons
Xa = R_all.T    # (images × neurons)
Xe = R_even.T   # (images × neurons)
Xo = R_odd.T    # (images × neurons)

print("\n🔹 FIRST PCA on stimulus-locked neural responses (all trials)...")
neural_pca_full = PCA(random_state=RANDOM_SEED).fit(Xa)
neural_cumvar = np.cumsum(neural_pca_full.explained_variance_ratio_)
neural_ncomp = np.searchsorted(neural_cumvar, VAR_CUTOFF) + 1

neural_pca = PCA(n_components=neural_ncomp, random_state=RANDOM_SEED)
Xa_pca = neural_pca.fit_transform(Xa)   # (images × neural_ncomp)
Xe_pca = neural_pca.transform(Xe)       # (images × neural_ncomp)
Xo_pca = neural_pca.transform(Xo)       # (images × neural_ncomp)

print(f"✅ Neural PCs (first stage) covering {VAR_CUTOFF*100:.0f}% variance: {neural_ncomp}")

# PCA basis in neuron space (neurons × neural_ncomp)
# sklearn: components_ is (n_components × n_features)
W_pca_neurons = neural_pca.components_.T

# ===============================================================
# STEP 3: cvPCA in neural PCA space
# ===============================================================
print("\n🔹 Running cvPCA on neural PCA scores (stimulus-locked)...")

n_stim = N_IMAGES

# Xe_pca and Xo_pca are already centered using the same mean in neuron space;
# we can treat them as zero-mean PC scores.
Xe0 = Xe_pca
Xo0 = Xo_pca

# Covariance of train (even) half in PCA space
Cb_pca = Xe0.T @ Xe0 / (n_stim - 1)      # (neural_ncomp × neural_ncomp)

# Eigen-decomposition in PCA space
eigvals, V_pca = np.linalg.eigh(Cb_pca)
idx = np.argsort(eigvals)[::-1]
eigvals = eigvals[idx]
V_pca = V_pca[:, idx]                    # (neural_ncomp × neural_ncomp)

# Project both halves onto these components (still in PCA space)
S1 = Xe0 @ V_pca                         # (images × neural_ncomp)
S2 = Xo0 @ V_pca                         # (images × neural_ncomp)

# Cross-validated variance per component
lam_cv = np.sum(S1 * S2, axis=0) / (n_stim - 1)   # (neural_ncomp,)

# Clamp negatives (noise)
lam_cv_pos = np.maximum(lam_cv, 0.0)
total_shared = lam_cv_pos.sum()
if total_shared <= 0:
    raise RuntimeError("Total shared variance (cvPCA) non-positive. Check data/splits.")

shared_frac = lam_cv_pos / total_shared
cum_shared_frac = np.cumsum(shared_frac)

# Pick number of cvPCA components by shared variance cutoff
brain_ncomp = np.searchsorted(cum_shared_frac, VAR_CUTOFF) + 1
brain_ncomp = min(brain_ncomp, V_pca.shape[1])

print("===== Neural cvPCA (in PCA space) =====")
for i in range(brain_ncomp):
    print(f"cvPC {i+1:2d}: shared var = {lam_cv_pos[i]:.6f} | "
          f"fraction = {shared_frac[i]*100:5.2f}% | "
          f"cumulative = {cum_shared_frac[i]*100:5.2f}%")

print(f"\n✅ Using first {brain_ncomp} cvPCA components as neural stimulus-locked basis "
      f"in PCA space (covering {cum_shared_frac[brain_ncomp-1]*100:.2f}% shared variance).")

# Neural cvPCA basis inside PCA space (neural_ncomp × brain_ncomp)
W_cvpca_pca = V_pca[:, :brain_ncomp]

# Now get neural cvPCA scores for ALL trials (Xa_pca) in this basis:
Zb_cv = Xa_pca @ W_cvpca_pca           # (images × brain_ncomp)

# Optionally, you can also get cvPCA basis back in neuron space:
# W_neural_cv = W_pca_neurons @ W_cvpca_pca   # (neurons × brain_ncomp)


# ===============================================================
# STEP 4: Cross-covariance between ViT PCs and neural cvPCA scores
# ===============================================================
print("\n🔹 Cross-covariance SVD between ViT PCs and neural cvPCA scores...")

# Center across images
Zv0 = Zv - Zv.mean(axis=0, keepdims=True)      # (images × vit_ncomp)
Zb0 = Zb_cv - Zb_cv.mean(axis=0, keepdims=True)  # (images × brain_ncomp)

# Cross-covariance
C_vb = (Zv0.T @ Zb0) / (n_stim - 1)            # (vit_ncomp × brain_ncomp)

# SVD of cross-covariance
U_cv, S_cv, Vt_cv = np.linalg.svd(C_vb, full_matrices=False)
V_cv = Vt_cv.T                                  # (brain_ncomp × r)

shared_cov_frac = (S_cv**2) / np.sum(S_cv**2)

print("===== Cross-covariance components (ViT ↔ neural cvPCA) =====")
for i, (s, frac) in enumerate(zip(S_cv, shared_cov_frac), start=1):
    print(f"Component {i:2d}: singular value = {s:.6f} | "
          f"cross-covariance fraction = {frac*100:5.2f}%")


# ===============================================================
# STEP 5: Variance explained in ORIGINAL neural PC data
#         by cross-covariance components
# ===============================================================
print("\n🔹 Variance explained in ORIGINAL neural PC data by cross-covariance components...")

# Original neural PC scores from FIRST PCA:
# Xa_pca: (images × neural_ncomp)
Xa_pca0 = Xa_pca - Xa_pca.mean(axis=0, keepdims=True)

# Total variance in original neural PCA space
total_var_neural_pca = np.sum(np.var(Xa_pca0, axis=0, ddof=1))

# Map cross-cov components from cvPCA space back into original neural PCA space:
# W_cvpca_pca: (neural_ncomp × brain_ncomp)
# V_cv:        (brain_ncomp × r)
# → B_pca:     (neural_ncomp × r), directions in original neural PCA space
B_pca = W_cvpca_pca @ V_cv                   # (neural_ncomp × r)

# Project original neural PC scores onto these cross-cov directions
Xb_cc_pca = Xa_pca0 @ B_pca                  # (images × r)

# Variance per cross-cov component in original neural PCA space
var_cc = np.var(Xb_cc_pca, axis=0, ddof=1)   # (r,)
frac_cc = var_cc / total_var_neural_pca
cum_frac_cc = np.cumsum(frac_cc)

print("===== Neural PCA variance explained by cross-covariance components =====")
for i, (f, cf) in enumerate(zip(frac_cc, cum_frac_cc), start=1):
    print(f"Cross-cov comp {i:2d}: "
          f"explained var in neural PCA space = {f*100:5.2f}% | "
          f"cumulative = {cf*100:5.2f}%")

print(f"\n✅ Total variance in ORIGINAL neural PC data accounted for "
      f"(sum over all cross-cov comps): {frac_cc.sum()*100:.2f}%")

# ===============================================================
# STEP 6: Save everything
# ===============================================================
out_name = f"vit_{AREA_NAME}_pca_cvpca_crosscov_results.npz"
np.savez(
    out_name,
    # ViT
    vit_scores=Zv,
    vit_basis=vit_pca.components_,
    vit_explained_var=vit_pca.explained_variance_ratio_,
    # Neural PCA
    neural_pca_scores=Xa_pca,
    neural_pca_basis=W_pca_neurons,
    neural_pca_explained_var=neural_pca.explained_variance_ratio_,
    # Neural cvPCA
    neural_cvpca_basis_pca=W_cvpca_pca,
    neural_cvpca_shared_var=lam_cv_pos[:brain_ncomp],
    neural_cvpca_shared_frac=shared_frac[:brain_ncomp],
    neural_cvpca_scores=Zb_cv,
    # Cross-covariance
    crosscov_matrix=C_vb,
    crosscov_singular_values=S_cv,
    crosscov_vit_basis=U_cv,
    crosscov_neural_cvpca_basis=V_cv,
    # Variance explained in ORIGINAL neural PCA space
    neural_pca_var_per_cc=var_cc,
    neural_pca_var_fraction_per_cc=frac_cc,
)

print(f"💾 Saved results to {out_name}")
# Out:
# 🔹 Loading ViT embeddings...
# 🔹 PCA on ViT CLR embeddings...
# ✅ ViT PCs covering 90% variance: 44
#
# 🔹 Loading neural responses, area = VISam...
#    → 2040 neurons, n_total=5900, inferred n_time=1
#    → Even trials: 25, odd trials: 25
#
# 🔹 FIRST PCA on stimulus-locked neural responses (all trials)...
# ✅ Neural PCs (first stage) covering 90% variance: 81
#
# 🔹 Running cvPCA on neural PCA scores (stimulus-locked)...
# ===== Neural cvPCA (in PCA space) =====
# cvPC  1: shared var = 0.440667 | fraction = 10.62% | cumulative = 10.62%
# cvPC  2: shared var = 0.341097 | fraction =  8.22% | cumulative = 18.83%
# cvPC  3: shared var = 0.251429 | fraction =  6.06% | cumulative = 24.89%
# cvPC  4: shared var = 0.180701 | fraction =  4.35% | cumulative = 29.24%
# cvPC  5: shared var = 0.144528 | fraction =  3.48% | cumulative = 32.73%
# cvPC  6: shared var = 0.130602 | fraction =  3.15% | cumulative = 35.87%
# cvPC  7: shared var = 0.105263 | fraction =  2.54% | cumulative = 38.41%
# cvPC  8: shared var = 0.103134 | fraction =  2.48% | cumulative = 40.89%
# cvPC  9: shared var = 0.092827 | fraction =  2.24% | cumulative = 43.13%
# cvPC 10: shared var = 0.095345 | fraction =  2.30% | cumulative = 45.43%
# cvPC 11: shared var = 0.076136 | fraction =  1.83% | cumulative = 47.26%
# cvPC 12: shared var = 0.063495 | fraction =  1.53% | cumulative = 48.79%
# cvPC 13: shared var = 0.061996 | fraction =  1.49% | cumulative = 50.28%
# cvPC 14: shared var = 0.061320 | fraction =  1.48% | cumulative = 51.76%
# cvPC 15: shared var = 0.061500 | fraction =  1.48% | cumulative = 53.24%
# cvPC 16: shared var = 0.055236 | fraction =  1.33% | cumulative = 54.57%
# cvPC 17: shared var = 0.057141 | fraction =  1.38% | cumulative = 55.95%
# cvPC 18: shared var = 0.052774 | fraction =  1.27% | cumulative = 57.22%
# cvPC 19: shared var = 0.050888 | fraction =  1.23% | cumulative = 58.45%
# cvPC 20: shared var = 0.046070 | fraction =  1.11% | cumulative = 59.56%
# cvPC 21: shared var = 0.047551 | fraction =  1.15% | cumulative = 60.70%
# cvPC 22: shared var = 0.046585 | fraction =  1.12% | cumulative = 61.82%
# cvPC 23: shared var = 0.041394 | fraction =  1.00% | cumulative = 62.82%
# cvPC 24: shared var = 0.045009 | fraction =  1.08% | cumulative = 63.91%
# cvPC 25: shared var = 0.044327 | fraction =  1.07% | cumulative = 64.97%
# cvPC 26: shared var = 0.039863 | fraction =  0.96% | cumulative = 65.93%
# cvPC 27: shared var = 0.039273 | fraction =  0.95% | cumulative = 66.88%
# cvPC 28: shared var = 0.039753 | fraction =  0.96% | cumulative = 67.84%
# cvPC 29: shared var = 0.037231 | fraction =  0.90% | cumulative = 68.74%
# cvPC 30: shared var = 0.034552 | fraction =  0.83% | cumulative = 69.57%
# cvPC 31: shared var = 0.035108 | fraction =  0.85% | cumulative = 70.41%
# cvPC 32: shared var = 0.034891 | fraction =  0.84% | cumulative = 71.25%
# cvPC 33: shared var = 0.035741 | fraction =  0.86% | cumulative = 72.11%
# cvPC 34: shared var = 0.034794 | fraction =  0.84% | cumulative = 72.95%
# cvPC 35: shared var = 0.033582 | fraction =  0.81% | cumulative = 73.76%
# cvPC 36: shared var = 0.033186 | fraction =  0.80% | cumulative = 74.56%
# cvPC 37: shared var = 0.032272 | fraction =  0.78% | cumulative = 75.34%
# cvPC 38: shared var = 0.031094 | fraction =  0.75% | cumulative = 76.09%
# cvPC 39: shared var = 0.031885 | fraction =  0.77% | cumulative = 76.86%
# cvPC 40: shared var = 0.028561 | fraction =  0.69% | cumulative = 77.54%
# cvPC 41: shared var = 0.029845 | fraction =  0.72% | cumulative = 78.26%
# cvPC 42: shared var = 0.026608 | fraction =  0.64% | cumulative = 78.90%
# cvPC 43: shared var = 0.028836 | fraction =  0.69% | cumulative = 79.60%
# cvPC 44: shared var = 0.026478 | fraction =  0.64% | cumulative = 80.24%
# cvPC 45: shared var = 0.026271 | fraction =  0.63% | cumulative = 80.87%
# cvPC 46: shared var = 0.027164 | fraction =  0.65% | cumulative = 81.52%
# cvPC 47: shared var = 0.027237 | fraction =  0.66% | cumulative = 82.18%
# cvPC 48: shared var = 0.027135 | fraction =  0.65% | cumulative = 82.83%
# cvPC 49: shared var = 0.026060 | fraction =  0.63% | cumulative = 83.46%
# cvPC 50: shared var = 0.025992 | fraction =  0.63% | cumulative = 84.09%
# cvPC 51: shared var = 0.025316 | fraction =  0.61% | cumulative = 84.70%
# cvPC 52: shared var = 0.023974 | fraction =  0.58% | cumulative = 85.28%
# cvPC 53: shared var = 0.023103 | fraction =  0.56% | cumulative = 85.83%
# cvPC 54: shared var = 0.024866 | fraction =  0.60% | cumulative = 86.43%
# cvPC 55: shared var = 0.024505 | fraction =  0.59% | cumulative = 87.02%
# cvPC 56: shared var = 0.023831 | fraction =  0.57% | cumulative = 87.60%
# cvPC 57: shared var = 0.025344 | fraction =  0.61% | cumulative = 88.21%
# cvPC 58: shared var = 0.023730 | fraction =  0.57% | cumulative = 88.78%
# cvPC 59: shared var = 0.023415 | fraction =  0.56% | cumulative = 89.34%
# cvPC 60: shared var = 0.021936 | fraction =  0.53% | cumulative = 89.87%
# cvPC 61: shared var = 0.023393 | fraction =  0.56% | cumulative = 90.43%
#
# ✅ Using first 61 cvPCA components as neural stimulus-locked basis in PCA space (covering 90.43% shared variance).
#
# 🔹 Cross-covariance SVD between ViT PCs and neural cvPCA scores...
# ===== Cross-covariance components (ViT ↔ neural cvPCA) =====
# Component  1: singular value = 5.540579 | cross-covariance fraction = 45.41%
# Component  2: singular value = 3.522301 | cross-covariance fraction = 18.35%
# Component  3: singular value = 2.040590 | cross-covariance fraction =  6.16%
# Component  4: singular value = 1.789837 | cross-covariance fraction =  4.74%
# Component  5: singular value = 1.601783 | cross-covariance fraction =  3.80%
# Component  6: singular value = 1.374342 | cross-covariance fraction =  2.79%
# Component  7: singular value = 1.269377 | cross-covariance fraction =  2.38%
# Component  8: singular value = 1.183447 | cross-covariance fraction =  2.07%
# Component  9: singular value = 1.061537 | cross-covariance fraction =  1.67%
# Component 10: singular value = 1.004206 | cross-covariance fraction =  1.49%
# Component 11: singular value = 0.926126 | cross-covariance fraction =  1.27%
# Component 12: singular value = 0.777008 | cross-covariance fraction =  0.89%
# Component 13: singular value = 0.763704 | cross-covariance fraction =  0.86%
# Component 14: singular value = 0.698807 | cross-covariance fraction =  0.72%
# Component 15: singular value = 0.685152 | cross-covariance fraction =  0.69%
# Component 16: singular value = 0.670986 | cross-covariance fraction =  0.67%
# Component 17: singular value = 0.639513 | cross-covariance fraction =  0.60%
# Component 18: singular value = 0.582344 | cross-covariance fraction =  0.50%
# Component 19: singular value = 0.570191 | cross-covariance fraction =  0.48%
# Component 20: singular value = 0.551218 | cross-covariance fraction =  0.45%
# Component 21: singular value = 0.516577 | cross-covariance fraction =  0.39%
# Component 22: singular value = 0.495554 | cross-covariance fraction =  0.36%
# Component 23: singular value = 0.482294 | cross-covariance fraction =  0.34%
# Component 24: singular value = 0.466669 | cross-covariance fraction =  0.32%
# Component 25: singular value = 0.450206 | cross-covariance fraction =  0.30%
# Component 26: singular value = 0.433715 | cross-covariance fraction =  0.28%
# Component 27: singular value = 0.415048 | cross-covariance fraction =  0.25%
# Component 28: singular value = 0.394896 | cross-covariance fraction =  0.23%
# Component 29: singular value = 0.365385 | cross-covariance fraction =  0.20%
# Component 30: singular value = 0.353871 | cross-covariance fraction =  0.19%
# Component 31: singular value = 0.322462 | cross-covariance fraction =  0.15%
# Component 32: singular value = 0.303597 | cross-covariance fraction =  0.14%
# Component 33: singular value = 0.300855 | cross-covariance fraction =  0.13%
# Component 34: singular value = 0.293256 | cross-covariance fraction =  0.13%
# Component 35: singular value = 0.273955 | cross-covariance fraction =  0.11%
# Component 36: singular value = 0.263929 | cross-covariance fraction =  0.10%
# Component 37: singular value = 0.242977 | cross-covariance fraction =  0.09%
# Component 38: singular value = 0.208710 | cross-covariance fraction =  0.06%
# Component 39: singular value = 0.204006 | cross-covariance fraction =  0.06%
# Component 40: singular value = 0.173903 | cross-covariance fraction =  0.04%
# Component 41: singular value = 0.161796 | cross-covariance fraction =  0.04%
# Component 42: singular value = 0.132150 | cross-covariance fraction =  0.03%
# Component 43: singular value = 0.113549 | cross-covariance fraction =  0.02%
# Component 44: singular value = 0.099197 | cross-covariance fraction =  0.01%
#
# 🔹 Variance explained in ORIGINAL neural PC data by cross-covariance components...
# ===== Neural PCA variance explained by cross-covariance components =====
# Cross-cov comp  1: explained var in neural PCA space =  7.27% | cumulative =  7.27%
# Cross-cov comp  2: explained var in neural PCA space =  5.63% | cumulative = 12.91%
# Cross-cov comp  3: explained var in neural PCA space =  3.72% | cumulative = 16.63%
# Cross-cov comp  4: explained var in neural PCA space =  2.94% | cumulative = 19.58%
# Cross-cov comp  5: explained var in neural PCA space =  3.63% | cumulative = 23.20%
# Cross-cov comp  6: explained var in neural PCA space =  2.61% | cumulative = 25.81%
# Cross-cov comp  7: explained var in neural PCA space =  2.75% | cumulative = 28.57%
# Cross-cov comp  8: explained var in neural PCA space =  2.97% | cumulative = 31.53%
# Cross-cov comp  9: explained var in neural PCA space =  1.80% | cumulative = 33.33%
# Cross-cov comp 10: explained var in neural PCA space =  1.51% | cumulative = 34.85%
# Cross-cov comp 11: explained var in neural PCA space =  1.98% | cumulative = 36.83%
# Cross-cov comp 12: explained var in neural PCA space =  1.63% | cumulative = 38.46%
# Cross-cov comp 13: explained var in neural PCA space =  1.51% | cumulative = 39.97%
# Cross-cov comp 14: explained var in neural PCA space =  1.68% | cumulative = 41.65%
# Cross-cov comp 15: explained var in neural PCA space =  1.17% | cumulative = 42.82%
# Cross-cov comp 16: explained var in neural PCA space =  1.44% | cumulative = 44.26%
# Cross-cov comp 17: explained var in neural PCA space =  1.60% | cumulative = 45.86%
# Cross-cov comp 18: explained var in neural PCA space =  1.37% | cumulative = 47.23%
# Cross-cov comp 19: explained var in neural PCA space =  1.02% | cumulative = 48.25%
# Cross-cov comp 20: explained var in neural PCA space =  1.12% | cumulative = 49.38%
# Cross-cov comp 21: explained var in neural PCA space =  1.32% | cumulative = 50.70%
# Cross-cov comp 22: explained var in neural PCA space =  1.13% | cumulative = 51.83%
# Cross-cov comp 23: explained var in neural PCA space =  1.03% | cumulative = 52.86%
# Cross-cov comp 24: explained var in neural PCA space =  1.50% | cumulative = 54.36%
# Cross-cov comp 25: explained var in neural PCA space =  1.18% | cumulative = 55.54%
# Cross-cov comp 26: explained var in neural PCA space =  1.09% | cumulative = 56.62%
# Cross-cov comp 27: explained var in neural PCA space =  1.07% | cumulative = 57.70%
# Cross-cov comp 28: explained var in neural PCA space =  0.96% | cumulative = 58.66%
# Cross-cov comp 29: explained var in neural PCA space =  1.03% | cumulative = 59.68%
# Cross-cov comp 30: explained var in neural PCA space =  1.21% | cumulative = 60.89%
# Cross-cov comp 31: explained var in neural PCA space =  0.92% | cumulative = 61.81%
# Cross-cov comp 32: explained var in neural PCA space =  0.82% | cumulative = 62.63%
# Cross-cov comp 33: explained var in neural PCA space =  0.96% | cumulative = 63.60%
# Cross-cov comp 34: explained var in neural PCA space =  1.33% | cumulative = 64.93%
# Cross-cov comp 35: explained var in neural PCA space =  0.92% | cumulative = 65.84%
# Cross-cov comp 36: explained var in neural PCA space =  0.87% | cumulative = 66.72%
# Cross-cov comp 37: explained var in neural PCA space =  0.93% | cumulative = 67.65%
# Cross-cov comp 38: explained var in neural PCA space =  0.90% | cumulative = 68.55%
# Cross-cov comp 39: explained var in neural PCA space =  0.98% | cumulative = 69.53%
# Cross-cov comp 40: explained var in neural PCA space =  0.86% | cumulative = 70.38%
# Cross-cov comp 41: explained var in neural PCA space =  0.90% | cumulative = 71.28%
# Cross-cov comp 42: explained var in neural PCA space =  0.91% | cumulative = 72.19%
# Cross-cov comp 43: explained var in neural PCA space =  1.11% | cumulative = 73.30%
# Cross-cov comp 44: explained var in neural PCA space =  1.00% | cumulative = 74.30%
#
# ✅ Total variance in ORIGINAL neural PC data accounted for (sum over all cross-cov comps): 74.30%
# 💾 Saved results to vit_VISam_pca_cvpca_crosscov_results.npz

# %%
import numpy as np
import pickle
from sklearn.decomposition import PCA
from scipy.special import softmax
from skbio.stats.composition import clr
import matplotlib.pyplot as plt   # 👈 add this

# ===============================================================
# STEP 6: Cross-correlations between ViT PCs and neural cvPCA scores
#         + histogram of correlation coefficients
# ===============================================================
print("\n🔹 Computing cross-correlations between ViT PCs and neural cvPCA scores...")

def compute_corr_matrix(A, B):
    """
    Compute correlation matrix between columns of A and B.

    A: (n_samples × p)
    B: (n_samples × q)

    Returns: (p × q) matrix of Pearson correlations.
    """
    if A.shape[0] != B.shape[0]:
        raise ValueError(f"Sample sizes don't match: {A.shape[0]} vs {B.shape[0]}")

    # Center
    A0 = A - A.mean(axis=0, keepdims=True)
    B0 = B - B.mean(axis=0, keepdims=True)

    # Standard deviations
    stdA = A0.std(axis=0, ddof=1)
    stdB = B0.std(axis=0, ddof=1)

    # Avoid division by zero
    stdA[stdA == 0] = np.nan
    stdB[stdB == 0] = np.nan

    # Correlation = cov / (σ_A σ_B)
    n = A.shape[0]
    corr = (A0.T @ B0) / ((n - 1) * np.outer(stdA, stdB))  # (p × q)

    return corr

# Here we correlate ViT PCs with *neural cvPCA scores* across images
#   Zv    : (images × vit_ncomp)
#   Zb_cv : (images × brain_ncomp)
corr_vit_neural_cvpca = compute_corr_matrix(Zv, Zb_cv)  # (vit_ncomp × brain_ncomp)

# Flatten for histogram, drop NaNs
corr_vals = corr_vit_neural_cvpca.flatten()
corr_vals = corr_vals[~np.isnan(corr_vals)]

print(f"   → Correlation matrix shape: {corr_vit_neural_cvpca.shape}")
print(f"   → Number of correlation coefficients used in histogram: {corr_vals.size}")

# Histogram of correlation coefficients
plt.figure(figsize=(6, 4))
plt.hist(corr_vals, bins=50, density=True)
plt.xlabel("Correlation coefficient (r)")
plt.ylabel("Density")
plt.title(f"ViT PC ↔ {AREA_NAME} neural cvPCA correlations")
plt.tight_layout()
hist_path = f"vit_{AREA_NAME}_vit_neural_cvpca_corr_hist.png"
plt.savefig(hist_path, dpi=150)
plt.close()

print(f"📊 Saved correlation histogram to {hist_path}")
# Out:
# 🔹 Computing cross-correlations between ViT PCs and neural cvPCA scores...
#    → Correlation matrix shape: (44, 61)
#    → Number of correlation coefficients used in histogram: 2684
# 📊 Saved correlation histogram to vit_VISam_vit_neural_cvpca_corr_hist.png
